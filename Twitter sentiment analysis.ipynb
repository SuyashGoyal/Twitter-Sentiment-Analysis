# %% [markdown]
# ### Loading Data

# %%
import numpy as np

# %%
import pandas as pd

# %%
train_data = pd.read_csv(r"C:\Users\HP\Twitter Sentiment Analysis\input\train.csv",encoding='ISO-8859-1')
train_data.shape
# Out:
# (99989, 3)

# %%
train_data
# Out:
#        ItemID  Sentiment                                      SentimentText
# 0           1          0                       is so sad for my APL frie...
# 1           2          0                     I missed the New Moon trail...
# 2           3          1                            omg its already 7:30 :O
# 3           4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5          0           i think mi bf is cheating on me!!!   ...
# ...       ...        ...                                                ...
# 99984   99996          0  @Cupcake  seems like a repeating problem   hop...
# 99985   99997          1  @cupcake__ arrrr we both replied to each other...
# 99986   99998          0                     @CuPcAkE_2120 ya i thought so
# 99987   99999          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99988  100000          1                    @cupcake_kayla haha yes you do
#
# [99989 rows x 3 columns]

# %%
train_data.drop_duplicates(subset='SentimentText', keep=False, inplace=True)

# %%
train_data
# Out:
#        ItemID  Sentiment                                      SentimentText
# 0           1          0                       is so sad for my APL frie...
# 1           2          0                     I missed the New Moon trail...
# 2           3          1                            omg its already 7:30 :O
# 3           4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5          0           i think mi bf is cheating on me!!!   ...
# ...       ...        ...                                                ...
# 99984   99996          0  @Cupcake  seems like a repeating problem   hop...
# 99985   99997          1  @cupcake__ arrrr we both replied to each other...
# 99986   99998          0                     @CuPcAkE_2120 ya i thought so
# 99987   99999          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99988  100000          1                    @cupcake_kayla haha yes you do
#
# [99989 rows x 3 columns]

# %% [markdown]
# ### Visualizing the tweets

# %%
#Taking a look at random tweets to gain insights
rand_indexs = np.random.randint(1,len(train_data),50).tolist()
train_data["SentimentText"][rand_indexs]
# Out:
# 32156    @AfricanKueen87    don't think im doin much th...
# 43401                       @angelzdope Don't like coffee
# 91889    @colinm53 Get 100 followers a day using www.tw...
# 68044    @amylovegrove I'm a little drunk and warm  close?
# 6786     #myweakness  Is music and i live to meet the p...
# 65079                                       @bjandcompany
# 62436     @bigwormy sounds interesting, whats that about?
# 92932    @bashsash fridayyy!  so so weird. what about y...
# 17667              ...ready to be confused all over again
# 69825    @bunnyteeth ps! would you like to make me a ba...
# 29556    @acummings we had rain for days on end so you ...
# 79332    @camillejaiden Dude.  Wow   Now I kind of sort...
# 9228       #bigupz to @cbondemand for knowing how to cook
# 69369    @bradjward you had to get me going on a gorgeo...
# 16177                                  ... Baby got Bumbo
# 22696                                @0mie I would never!
# 12855    *spazzes* I also desperately wana see &quot;Ha...
# 11686    (...) Blake Lewis, Jon McLaughlin, Ryan Star a...
# 16919    ? Listen to 'Tension' by Voutloos http://bln.k...
# 83441    @ChicoLaura We've been watching Heroes, too. W...
# 21424    @_CrC_ Happy Birthday since it past midnight w...
# 67010    @brittanytastic xD hallÃ¥ pÃ¥ dig med, umm, ha...
# 80350    @chantelleaustin i just wasn't thematically pl...
# 82693    @cascandar My excitement will likely keep me a...
# 13150    . @geektyrant I love your site. I really do. Y...
# 57447    @bazutti Happy pre-Birthday  You're not freaki...
# 9286     #canada telecoms launch overpriced #mobile pay...
# 47526    @arengolucky Oooh, wish I could! Yucky weather...
# 63184    @blprnt Internet Week! Is there also an Electr...
# 95919    @ClaireFry cool,  doing things on your own in ...
# 82341                              @carrot_girl lmaoooooo
# 49220       @amanda_loves_jb some have early return fees.
# 72076    @angelandz My favorite part of Muppet Babies w...
# 7478     #iwould love to see all my old friends from ca...
# 24816    @30SECONDSTOMARS  the new cd is gonna be amazi...
# 59067    @benpatrick90069  that sucks but K.I.M. (Keep ...
# 44359             @AnnetteStatus why won't you talk to me
# 71284    @andykemp will be third time I've seen them. T...
# 99808    @crystalchappell G'night! Thanks for the tweets.
# 13413    . o O ( ahh - minute (time) vs minute (small) ...
# 84675                @ateague28 you're making me homesick
# 30433    @adccfighter with big cuts, 24 hours is just n...
# 59157    @BenRoehlen Formal deposit must mean that you ...
# 31730    @AdventureFarm Was the least I could do, looks...
# 80792             @arunsdevine Karl Marx won, CP(I)M lost
# 75419    @BubblesBBW haha thank you, doll! I'm on now i...
# 27588    @abbylatif just enjoy looking at tweety bird a...
# 47482    @allyheartsBB i love the guitar solo.. JT need...
# 62654                       @blcsfo I dunno *you* tell me
# 23559                                   @16pebbles I know
# Name: SentimentText, dtype: object

# %% [markdown]
# #### Emoticons
# The internet language includes so many emoticons, people also tend to create their own, so we will first analyze the emoticons included in our dataset, try to classify them as happy and said, and make sure that our model know about them.

# %%
#Finding what emoticons have been used in out dataset
import re
tweets_text = train_data.SentimentText.str.cat()
emos = set(re.findall(r" ([xX:;][-']?.) ",tweets_text))
emos_count = []
for emo in emos:
    emos_count.append((tweets_text.count(emo), emo))
sorted(emos_count,reverse=True)
# Out:
# [(3281, ':/'),
#  (2874, 'x '),
#  (2626, ': '),
#  (1339, 'x@'),
#  (1214, 'xx'),
#  (1162, 'xa'),
#  (984, ';3'),
#  (887, 'xp'),
#  (842, 'xo'),
#  (713, ';)'),
#  (483, 'xe'),
#  (431, ';I'),
#  (353, ';.'),
#  (254, 'xD'),
#  (251, 'x.'),
#  (245, '::'),
#  (234, 'X '),
#  (217, ';t'),
#  (209, ';s'),
#  (185, ':O'),
#  (176, ':3'),
#  (166, ';D'),
#  (159, ":'"),
#  (157, 'XD'),
#  (146, 'x3'),
#  (142, ':p'),
#  (126, ":'("),
#  (118, ':@'),
#  (117, 'xh'),
#  (117, ':S'),
#  (109, 'xm'),
#  (104, ';p'),
#  (104, ';-)'),
#  (92, ':|'),
#  (91, 'x,'),
#  (89, ';P'),
#  (76, 'xd'),
#  (75, ';o'),
#  (75, ';d'),
#  (71, ':o'),
#  (65, 'XX'),
#  (63, ':L'),
#  (59, 'Xx'),
#  (59, ':1'),
#  (58, ':]'),
#  (57, ':s'),
#  (56, ':0'),
#  (54, 'XO'),
#  (44, ';;'),
#  (43, ';('),
#  (38, ':-D'),
#  (37, 'xk'),
#  (36, 'XT'),
#  (35, 'x?'),
#  (35, 'x)'),
#  (34, 'x2'),
#  (33, ';/'),
#  (32, 'x:'),
#  (32, ':\\'),
#  (31, 'x-'),
#  (27, 'Xo'),
#  (27, 'XP'),
#  (27, ':-/'),
#  (26, ':-P'),
#  (25, ':*'),
#  (23, 'xX'),
#  (22, ":')"),
#  (17, 'xP'),
#  (16, ':['),
#  (16, ':-p'),
#  (14, 'x]'),
#  (14, 'XM'),
#  (13, ':-O'),
#  (12, 'x('),
#  (12, 'X1'),
#  (12, ':x'),
#  (11, 'XS'),
#  (11, ':l'),
#  (10, 'x*'),
#  (10, 'X.'),
#  (10, ':b'),
#  (10, ':T'),
#  (9, ';]'),
#  (9, ':I'),
#  (8, ':C'),
#  (7, ';-('),
#  (7, ':-|'),
#  (6, 'X,'),
#  (6, ':-o'),
#  (6, ':-\\'),
#  (6, ':-*'),
#  (6, ':$'),
#  (5, 'XL'),
#  (5, ':d'),
#  (5, ':X'),
#  (5, ':H'),
#  (5, ':?'),
#  (5, ':-S'),
#  (4, ';-D'),
#  (3, ':Z'),
#  (3, ':E'),
#  (3, ':-s'),
#  (3, ':-['),
#  (3, ':-X'),
#  (2, 'X5'),
#  (2, 'X-('),
#  (2, "X's"),
#  (2, ';-;'),
#  (2, ':}'),
#  (2, ':D'),
#  (2, ':;'),
#  (2, ":'D"),
#  (1, 'x|'),
#  (1, "x'd"),
#  (1, "x'D"),
#  (1, ';-|'),
#  (1, ';-/'),
#  (1, ':-x'),
#  (1, ':-h'),
#  (1, ':-]'),
#  (1, ':-W'),
#  (1, ':-$'),
#  (1, ':('),
#  (1, ":'[")]

# %% [markdown]
# We should by now know which emoticons are used (and its frequency) to build two regex, one for the happy ones and another for the sad ones. We will then use them in the preprocessing process to mark them as using happy emoticons or sad ones.

# %%
HAPPY_EMO = r" ([xX;:]-?[dD)]|:-?[\)]|[;:][pP]) "
SAD_EMO = r" (:'?[/|\(]) "
print("Happy emoticons:", set(re.findall(HAPPY_EMO, tweets_text)))
print("Sad emoticons:", set(re.findall(SAD_EMO, tweets_text)))
# Out:
# Happy emoticons: {';d', ';-D', ';p', ':d', 'XD', ';)', 'x)', ':D', 'xd', ';P', ';D', ':p', 'xD', ';-)', ':-D'}
# Sad emoticons: {':|', ":'(", ':/', ':('}

# %% [markdown]
# #### Most used Words
# What we are going to do next is to define a function that will show us top words, so we may fix things before running our learning algorithm. This function takes as input a text and output words sorted according to their frequency, starting with the most used word.

# %%
import nltk
from nltk.tokenize import word_tokenize

#nltk.download('punkt')
def most_used_words(text):
    tokens = word_tokenize(text)
    frequency_dist = nltk.FreqDist(tokens)
    print("There is %d different words" % len(set(tokens)))
    return sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)

# %%
most_used_words(train_data.SentimentText.str.cat())[:100]
# Out:
# There is 128915 different words
# ['@',
#  '!',
#  '.',
#  'I',
#  ',',
#  'to',
#  'the',
#  'you',
#  '?',
#  'a',
#  'it',
#  'i',
#  ';',
#  'and',
#  '&',
#  '...',
#  'my',
#  'for',
#  'is',
#  'that',
#  "'s",
#  "n't",
#  'in',
#  'me',
#  'of',
#  'have',
#  'on',
#  'quot',
#  "'m",
#  'so',
#  ':',
#  'but',
#  '#',
#  'do',
#  'was',
#  'be',
#  '..',
#  'not',
#  'your',
#  'are',
#  'just',
#  'with',
#  'like',
#  '-',
#  'at',
#  '*',
#  'too',
#  'get',
#  'good',
#  'u',
#  'up',
#  'know',
#  'all',
#  'this',
#  'now',
#  'no',
#  'we',
#  'out',
#  ')',
#  'love',
#  'lol',
#  'can',
#  'what',
#  'one',
#  '(',
#  'will',
#  'go',
#  'about',
#  'did',
#  'got',
#  "'ll",
#  'there',
#  'amp',
#  'day',
#  'http',
#  'see',
#  "'re",
#  'if',
#  'time',
#  'they',
#  'think',
#  'as',
#  'when',
#  'from',
#  'You',
#  'It',
#  'going',
#  'really',
#  'well',
#  'am',
#  'work',
#  'had',
#  'would',
#  'how',
#  'he',
#  'here',
#  'thanks',
#  'some',
#  '....',
#  'haha']

# %% [markdown]
# #### Stop Words
# What we can see is that stop words are the most used, but in fact they don't help us determine if a tweet is happy/sad, however, they are consuming memory and they are making the learning process slower, so we really need to get rid of them.

# %%
from nltk.corpus import stopwords

#nltk.download("stopwords")

mw = most_used_words(train_data.SentimentText.str.cat())
most_words = []
for w in mw:
    if len(most_words) == 1000:
        break
    if w in stopwords.words("english"):
        continue
    else:
        most_words.append(w)
# Out:
# There is 128915 different words

# %%
#Getting a look over the top 1000 words
sorted(most_words)
# Out:
# ['!',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  "'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '--',
#  '.',
#  '..',
#  '...',
#  '....',
#  '.....',
#  '......',
#  '/',
#  '1',
#  '10',
#  '100',
#  '12',
#  '1st',
#  '2',
#  '20',
#  '2nd',
#  '3',
#  '30',
#  '30SECONDSTOMARS',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  ':',
#  ';',
#  '=',
#  '?',
#  '@',
#  'A',
#  'AND',
#  'Ah',
#  'AlexAllTimeLow',
#  'All',
#  'Also',
#  'Alyssa_Milano',
#  'Am',
#  'And',
#  'Are',
#  'As',
#  'At',
#  'Aw',
#  'Awesome',
#  'Aww',
#  'Awww',
#  'BSB',
#  'Birthday',
#  'But',
#  'Ca',
#  'Can',
#  'Chris',
#  'Come',
#  'Congrats',
#  'Cool',
#  'D',
#  'DM',
#  'DO',
#  'Damn',
#  'Day',
#  'Did',
#  'Do',
#  'Enjoy',
#  'FF',
#  'Follow',
#  'FollowFriday',
#  'For',
#  'Friday',
#  'Get',
#  'Glad',
#  'Go',
#  'God',
#  'Good',
#  'Got',
#  'Great',
#  'Had',
#  'Haha',
#  'Happy',
#  'Have',
#  'He',
#  'Hello',
#  'Hey',
#  'Hi',
#  'Hope',
#  'How',
#  'I',
#  'IS',
#  'IT',
#  'If',
#  'Im',
#  'In',
#  'Is',
#  'It',
#  'Its',
#  'July',
#  'June',
#  'Just',
#  'Keep',
#  'LA',
#  'LMAO',
#  'LOL',
#  'LOVE',
#  'Let',
#  'Like',
#  'Lol',
#  'London',
#  'Love',
#  'ME',
#  'MY',
#  'Maybe',
#  'Me',
#  'Monday',
#  'Morning',
#  'My',
#  'NO',
#  'NOT',
#  'New',
#  'Nice',
#  'Night',
#  'No',
#  'Not',
#  'Now',
#  'O',
#  'OK',
#  'OMG',
#  'Of',
#  'Oh',
#  'Ok',
#  'On',
#  'Once',
#  'One',
#  'Only',
#  'Or',
#  'Please',
#  'Poor',
#  'Really',
#  'S',
#  'SO',
#  'Saturday',
#  'See',
#  'She',
#  'So',
#  'Sorry',
#  'Sounds',
#  'Still',
#  'Sunday',
#  'THAT',
#  'THE',
#  'TO',
#  'TV',
#  'Tell',
#  'Thank',
#  'Thanks',
#  'That',
#  'The',
#  'Then',
#  'There',
#  'They',
#  'This',
#  'To',
#  'Too',
#  'Twitter',
#  'U',
#  'UK',
#  'US',
#  'Very',
#  'Was',
#  'We',
#  'Welcome',
#  'Well',
#  'What',
#  'When',
#  'Where',
#  'Who',
#  'Why',
#  'Will',
#  'Wish',
#  'Would',
#  'Wow',
#  'XD',
#  'YAY',
#  'YES',
#  'YOU',
#  'Yay',
#  'Yeah',
#  'Yep',
#  'Yes',
#  'You',
#  'Your',
#  '[',
#  ']',
#  'able',
#  'absolutely',
#  'account',
#  'actually',
#  'add',
#  'afternoon',
#  'ago',
#  'agree',
#  'ah',
#  'ahh',
#  'aint',
#  'air',
#  'album',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'already',
#  'alright',
#  'also',
#  'always',
#  'amazing',
#  'amp',
#  'andyclemmensen',
#  'annoying',
#  'another',
#  'answer',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'aplusk',
#  'app',
#  'apparently',
#  'appreciate',
#  'around',
#  'ashleytisdale',
#  'ask',
#  'asked',
#  'asleep',
#  'ass',
#  'aw',
#  'awake',
#  'away',
#  'awesome',
#  'aww',
#  'awww',
#  'awwww',
#  'b',
#  'babe',
#  'baby',
#  'babygirlparis',
#  'back',
#  'backstreetboys',
#  'bad',
#  'band',
#  'bday',
#  'beach',
#  'beat',
#  'beautiful',
#  'bed',
#  'beer',
#  'behind',
#  'believe',
#  'best',
#  'bet',
#  'better',
#  'big',
#  'billyraycyrus',
#  'birthday',
#  'bit',
#  'bitch',
#  'black',
#  'blog',
#  'blue',
#  'body',
#  'boo',
#  'book',
#  'books',
#  'bored',
#  'boring',
#  'bought',
#  'bout',
#  'box',
#  'boy',
#  'boys',
#  'bradiewebbstack',
#  'break',
#  'breakfast',
#  'bring',
#  'bro',
#  'broke',
#  'broken',
#  'brother',
#  'btw',
#  'business',
#  'busy',
#  'buy',
#  'c',
#  'ca',
#  'cake',
#  'call',
#  'called',
#  'came',
#  'camera',
#  'cant',
#  'car',
#  'care',
#  'case',
#  'cat',
#  'catch',
#  'cause',
#  'chance',
#  'change',
#  'chat',
#  'check',
#  'chocolate',
#  'city',
#  'class',
#  'close',
#  'club',
#  'coffee',
#  'cold',
#  'come',
#  'comes',
#  'coming',
#  'comment',
#  'computer',
#  'concert',
#  'congrats',
#  'cool',
#  'cos',
#  'could',
#  'couple',
#  'course',
#  'coz',
#  'crap',
#  'crazy',
#  'cream',
#  'cry',
#  'crying',
#  'cut',
#  'cute',
#  'cuz',
#  'da',
#  'dad',
#  'damn',
#  'dance',
#  'date',
#  'day',
#  'days',
#  'dead',
#  'deal',
#  'dear',
#  'def',
#  'definitely',
#  'didnt',
#  'die',
#  'died',
#  'different',
#  'dinner',
#  'doesnt',
#  'dog',
#  'done',
#  'dont',
#  'dream',
#  'dreams',
#  'drink',
#  'drive',
#  'dude',
#  'due',
#  'dunno',
#  'earlier',
#  'early',
#  'easy',
#  'eat',
#  'eating',
#  'eh',
#  'either',
#  'else',
#  'em',
#  'email',
#  'end',
#  'enjoy',
#  'enjoyed',
#  'enjoying',
#  'enough',
#  'especially',
#  'etc',
#  'even',
#  'evening',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'exactly',
#  'exam',
#  'exams',
#  'except',
#  'excited',
#  'exciting',
#  'eye',
#  'eyes',
#  'face',
#  'facebook',
#  'fact',
#  'fail',
#  'fair',
#  'fall',
#  'family',
#  'fan',
#  'fans',
#  'far',
#  'fast',
#  'favorite',
#  'feel',
#  'feeling',
#  'feels',
#  'fell',
#  'felt',
#  'figure',
#  'film',
#  'finally',
#  'find',
#  'fine',
#  'finish',
#  'finished',
#  'first',
#  'fix',
#  'flight',
#  'follow',
#  'followers',
#  'followfriday',
#  'following',
#  'food',
#  'forever',
#  'forget',
#  'forgot',
#  'forward',
#  'found',
#  'free',
#  'friday',
#  'friend',
#  'friends',
#  'front',
#  'fuck',
#  'fucking',
#  'full',
#  'fun',
#  'funny',
#  'future',
#  'game',
#  'gave',
#  'get',
#  'gets',
#  'getting',
#  'girl',
#  'girls',
#  'give',
#  'giving',
#  'glad',
#  'go',
#  'god',
#  'goes',
#  'goin',
#  'going',
#  'gon',
#  'gone',
#  'good',
#  'goodnight',
#  'gorgeous',
#  'got',
#  'great',
#  'green',
#  'gt',
#  'guess',
#  'guy',
#  'guys',
#  'ha',
#  'haha',
#  'hahah',
#  'hahaha',
#  'hair',
#  'half',
#  'hand',
#  'hands',
#  'hang',
#  'happen',
#  'happened',
#  'happens',
#  'happy',
#  'hard',
#  'hate',
#  'havent',
#  'head',
#  'hear',
#  'heard',
#  'heart',
#  'hehe',
#  'hell',
#  'hello',
#  'help',
#  'hey',
#  'hi',
#  'high',
#  'hit',
#  'hmm',
#  'hold',
#  'home',
#  'hope',
#  'hopefully',
#  'hoping',
#  'horrible',
#  'hot',
#  'hour',
#  'hours',
#  'house',
#  'http',
#  'hug',
#  'huge',
#  'hugs',
#  'huh',
#  'hun',
#  'hungry',
#  'hurt',
#  'hurts',
#  'iPhone',
#  'ice',
#  'idea',
#  'idk',
#  'ill',
#  'im',
#  'inaperfectworld',
#  'indeed',
#  'info',
#  'instead',
#  'interesting',
#  'internet',
#  'invite',
#  'iremember',
#  'ive',
#  'jealous',
#  'job',
#  'join',
#  'keep',
#  'keeps',
#  'kid',
#  'kidding',
#  'kids',
#  'kill',
#  'kind',
#  'kinda',
#  'knew',
#  'know',
#  'knows',
#  'lady',
#  'lame',
#  'laptop',
#  'last',
#  'late',
#  'lately',
#  'later',
#  'laugh',
#  'learn',
#  'least',
#  'leave',
#  'leaving',
#  'left',
#  'less',
#  'let',
#  'lets',
#  'life',
#  'like',
#  'liked',
#  'lil',
#  'line',
#  'link',
#  'list',
#  'listen',
#  'listening',
#  'little',
#  'live',
#  'living',
#  'lmao',
#  'lol',
#  'long',
#  'longer',
#  'look',
#  'looked',
#  'looking',
#  'looks',
#  'lose',
#  'lost',
#  'lot',
#  'lots',
#  'love',
#  'loved',
#  'lovely',
#  'loves',
#  'lt',
#  'luck',
#  'lucky',
#  'lunch',
#  'luv',
#  'mad',
#  'made',
#  'make',
#  'makes',
#  'making',
#  'man',
#  'many',
#  'mate',
#  'matter',
#  'may',
#  'maybe',
#  'mean',
#  'means',
#  'meant',
#  'meet',
#  'meeting',
#  'mention',
#  'message',
#  'met',
#  'might',
#  'mind',
#  'mine',
#  'minute',
#  'minutes',
#  'miss',
#  'missed',
#  'missing',
#  'mom',
#  'moment',
#  'monday',
#  'money',
#  'month',
#  'months',
#  'mood',
#  'morning',
#  'move',
#  'movie',
#  'movies',
#  'moving',
#  'much',
#  'mum',
#  'music',
#  'musicmonday',
#  'must',
#  'myspace',
#  'myweakness',
#  'n',
#  "n't",
#  'na',
#  'name',
#  'near',
#  'need',
#  'needed',
#  'needs',
#  'never',
#  'new',
#  'news',
#  'next',
#  'nice',
#  'night',
#  'nite',
#  'nope',
#  'nothing',
#  'number',
#  'office',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'omg',
#  'one',
#  'ones',
#  'online',
#  'open',
#  'order',
#  'others',
#  'outside',
#  'p',
#  'page',
#  'pain',
#  'parents',
#  'part',
#  'party',
#  'pass',
#  'past',
#  'pay',
#  'people',
#  'perfect',
#  'person',
#  'phone',
#  'photo',
#  'photos',
#  'pic',
#  'pick',
#  'pics',
#  'picture',
#  'pictures',
#  'place',
#  'plan',
#  'plans',
#  'play',
#  'played',
#  'playing',
#  'please',
#  'plus',
#  'point',
#  'pool',
#  'poor',
#  'post',
#  'posted',
#  'ppl',
#  'pretty',
#  'prob',
#  'probably',
#  'problem',
#  'profile',
#  'proud',
#  'put',
#  'question',
#  'quite',
#  'quot',
#  'r',
#  'radio',
#  'rain',
#  'raining',
#  'random',
#  'rather',
#  'read',
#  'reading',
#  'ready',
#  'real',
#  'really',
#  'reason',
#  'red',
#  'remember',
#  'reply',
#  'rest',
#  'ride',
#  'right',
#  'rock',
#  'room',
#  'run',
#  'running',
#  'sad',
#  'sadly',
#  'safe',
#  'said',
#  'save',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'scared',
#  'school',
#  'season',
#  'second',
#  'see',
#  'seeing',
#  'seem',
#  'seems',
#  'seen',
#  'self',
#  'send',
#  'sense',
#  'sent',
#  'serious',
#  'seriously',
#  'set',
#  'sexy',
#  'shall',
#  'shame',
#  'share',
#  'sharing',
#  'shit',
#  'shopping',
#  'short',
#  'show',
#  'shows',
#  'shut',
#  'sick',
#  'side',
#  'sigh',
#  'sign',
#  'silly',
#  'since',
#  'single',
#  'sis',
#  'sister',
#  'site',
#  'sitting',
#  'sleep',
#  'sleeping',
#  'slow',
#  'small',
#  'smile',
#  'sold',
#  'someone',
#  'something',
#  'sometimes',
#  'somewhere',
#  'son',
#  'song',
#  'songs',
#  'soo',
#  'soon',
#  'sooo',
#  'soooo',
#  'sorry',
#  'sort',
#  'sound',
#  'sounds',
#  'special',
#  'squarespace',
#  'start',
#  'started',
#  'starting',
#  'stay',
#  'still',
#  'stop',
#  'store',
#  'story',
#  'stuck',
#  'study',
#  'stuff',
#  'stupid',
#  'suck',
#  'sucks',
#  'summer',
#  'sun',
#  'sunday',
#  'sunny',
#  'super',
#  'support',
#  'supposed',
#  'sure',
#  'sweet',
#  'sweetie',
#  'ta',
#  'take',
#  'taken',
#  'taking',
#  'talk',
#  'talking',
#  'tea',
#  'team',
#  'tell',
#  'text',
#  'thank',
#  'thanks',
#  'thats',
#  'thing',
#  'things',
#  'think',
#  'thinking',
#  'tho',
#  'though',
#  'thought',
#  'three',
#  'thx',
#  'tickets',
#  'til',
#  'till',
#  'time',
#  'times',
#  'tired',
#  'today',
#  'together',
#  'told',
#  'tomorrow',
#  'tonight',
#  'took',
#  'top',
#  'totally',
#  'touch',
#  'tour',
#  'town',
#  'train',
#  'tried',
#  'trip',
#  'true',
#  'try',
#  'trying',
#  'turn',
#  'tv',
#  'tweet',
#  'tweeting',
#  'tweets',
#  'twitter',
#  'two',
#  'type',
#  'u',
#  'ugh',
#  'understand',
#  'unfortunately',
#  'update',
#  'updates',
#  'upset',
#  'ur',
#  'us',
#  'use',
#  'used',
#  'using',
#  'usually',
#  'version',
#  'via',
#  'video',
#  'vip',
#  'visit',
#  'voice',
#  'vote',
#  'w/',
#  'wait',
#  'waiting',
#  'wake',
#  'walk',
#  'wan',
#  'want',
#  'wanted',
#  'wants',
#  'warm',
#  'watch',
#  'watched',
#  'watching',
#  'water',
#  'way',
#  'wear',
#  'weather',
#  'website',
#  'wedding',
#  'week',
#  'weekend',
#  'weeks',
#  'weird',
#  'welcome',
#  'well',
#  'went',
#  'whatever',
#  'whats',
#  'white',
#  'whole',
#  'win',
#  'wine',
#  'wish',
#  'wit',
#  'without',
#  'wo',
#  'woke',
#  'woman',
#  'wonder',
#  'wonderful',
#  'wont',
#  'word',
#  'words',
#  'work',
#  'worked',
#  'working',
#  'works',
#  'world',
#  'worry',
#  'worse',
#  'worst',
#  'worth',
#  'would',
#  'wow',
#  'write',
#  'writing',
#  'wrong',
#  'x',
#  'xD',
#  'xoxo',
#  'xx',
#  'xxx',
#  'ya',
#  'yay',
#  'yea',
#  'yeah',
#  'year',
#  'years',
#  'yep',
#  'yes',
#  'yesterday',
#  'yet',
#  'yo',
#  'youtube',
#  'yup',
#  '|',
#  '~',
#  '»']

# %% [markdown]
# #### Stemming
# As we can observe, there are several words having the same meaning but have been written in a different manner,sometimes in the plural from and sometimes in the suffix. This would make our model think that they are different words,also making our vocab bigger, thus wasting memory and time for the llearning process.

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

#nltk.download('wordnet')

def stem_tokenize(text):
    stemmer = SnowballStemmer("english")
    stemmer = WordNetLemmatizer()
    return [stemmer.lemmatize(token) for token in word_tokenize(text)]

def lemmatize_tokenize(text):
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(token) for token in word_tokenize(text)]

# %%
##Inserted later
stem_tokenize(train_data.SentimentText.str.cat())
# Out:
# ['is',
#  'so',
#  'sad',
#  'for',
#  'my',
#  'APL',
#  'friend',
#  '.............',
#  'I',
#  'missed',
#  'the',
#  'New',
#  'Moon',
#  'trailer',
#  '...',
#  'omg',
#  'it',
#  'already',
#  '7:30',
#  ':',
#  'O',
#  '..',
#  'Omgaga',
#  '.',
#  'Im',
#  'sooo',
#  'im',
#  'gunna',
#  'CRy',
#  '.',
#  'I',
#  "'ve",
#  'been',
#  'at',
#  'this',
#  'dentist',
#  'since',
#  '11',
#  '..',
#  'I',
#  'wa',
#  'suposed',
#  '2',
#  'just',
#  'get',
#  'a',
#  'crown',
#  'put',
#  'on',
#  '(',
#  '30mins',
#  ')',
#  '...',
#  'i',
#  'think',
#  'mi',
#  'bf',
#  'is',
#  'cheating',
#  'on',
#  'me',
#  '!',
#  '!',
#  '!',
#  'T_T',
#  'or',
#  'i',
#  'just',
#  'worry',
#  'too',
#  'much',
#  '?',
#  'Juuuuuuuuuuuuuuuuussssst',
#  'Chillin',
#  '!',
#  '!',
#  'Sunny',
#  'Again',
#  'Work',
#  'Tomorrow',
#  ':',
#  '-|',
#  'TV',
#  'Tonight',
#  'handed',
#  'in',
#  'my',
#  'uniform',
#  'today',
#  '.',
#  'i',
#  'miss',
#  'you',
#  'already',
#  'hmmmm',
#  '....',
#  'i',
#  'wonder',
#  'how',
#  'she',
#  'my',
#  'number',
#  '@',
#  '-',
#  ')',
#  'I',
#  'must',
#  'think',
#  'about',
#  'positive',
#  '..',
#  'thanks',
#  'to',
#  'all',
#  'the',
#  'hater',
#  'up',
#  'in',
#  'my',
#  'face',
#  'all',
#  'day',
#  '!',
#  '112-102',
#  'this',
#  'weekend',
#  'ha',
#  'sucked',
#  'so',
#  'far',
#  'jb',
#  'isnt',
#  'showing',
#  'in',
#  'australia',
#  'any',
#  'more',
#  '!',
#  'ok',
#  'thats',
#  'it',
#  'you',
#  'win',
#  '.',
#  '&',
#  'lt',
#  ';',
#  '--',
#  '--',
#  '--',
#  '--',
#  'This',
#  'is',
#  'the',
#  'way',
#  'i',
#  'feel',
#  'right',
#  'now',
#  '...',
#  'awhhe',
#  'man',
#  '....',
#  'I',
#  "'m",
#  'completely',
#  'useless',
#  'rt',
#  'now',
#  '.',
#  'Funny',
#  ',',
#  'all',
#  'I',
#  'can',
#  'do',
#  'is',
#  'twitter',
#  '.',
#  'http',
#  ':',
#  '//myloc.me/27HX',
#  'Feeling',
#  'strangely',
#  'fine',
#  '.',
#  'Now',
#  'I',
#  "'m",
#  'gon',
#  'na',
#  'go',
#  'listen',
#  'to',
#  'some',
#  'Semisonic',
#  'to',
#  'celebrate',
#  'HUGE',
#  'roll',
#  'of',
#  'thunder',
#  'just',
#  'now',
#  '...',
#  'SO',
#  'scary',
#  '!',
#  '!',
#  '!',
#  '!',
#  'I',
#  'just',
#  'cut',
#  'my',
#  'beard',
#  'off',
#  '.',
#  'It',
#  "'s",
#  'only',
#  'been',
#  'growing',
#  'for',
#  'well',
#  'over',
#  'a',
#  'year',
#  '.',
#  'I',
#  "'m",
#  'gon',
#  'na',
#  'start',
#  'it',
#  'over',
#  '.',
#  '@',
#  'shaunamanu',
#  'is',
#  'happy',
#  'in',
#  'the',
#  'meantime',
#  '.',
#  'Very',
#  'sad',
#  'about',
#  'Iran',
#  '.',
#  'wompppp',
#  'wompp',
#  'You',
#  "'re",
#  'the',
#  'only',
#  'one',
#  'who',
#  'can',
#  'see',
#  'this',
#  'cause',
#  'no',
#  'one',
#  'else',
#  'is',
#  'following',
#  'me',
#  'this',
#  'is',
#  'for',
#  'you',
#  'because',
#  'you',
#  "'re",
#  'pretty',
#  'awesome',
#  '&',
#  'lt',
#  ';',
#  '--',
#  '-Sad',
#  'level',
#  'is',
#  '3',
#  '.',
#  'I',
#  'wa',
#  'writing',
#  'a',
#  'massive',
#  'blog',
#  'tweet',
#  'on',
#  'Myspace',
#  'and',
#  'my',
#  'comp',
#  'shut',
#  'down',
#  '.',
#  'Now',
#  'it',
#  "'s",
#  'all',
#  'lost',
#  '*',
#  'lay',
#  'in',
#  'fetal',
#  'position',
#  '*',
#  '...',
#  'Headed',
#  'to',
#  'Hospitol',
#  ':',
#  'Had',
#  'to',
#  'pull',
#  'out',
#  'of',
#  'the',
#  'Golf',
#  'Tourny',
#  'in',
#  '3rd',
#  'place',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  'I',
#  'Think',
#  'I',
#  'Re-Ripped',
#  'something',
#  '!',
#  '!',
#  '!',
#  'Yeah',
#  'THAT',
#  '!',
#  '!',
#  'BoRinG',
#  ')',
#  ':',
#  'whats',
#  'wrong',
#  'with',
#  'him',
#  '?',
#  '?',
#  'Please',
#  'tell',
#  'me',
#  '........',
#  ':',
#  '-/',
#  'ca',
#  "n't",
#  'be',
#  'bothered',
#  '.',
#  'i',
#  'wish',
#  'i',
#  'could',
#  'spend',
#  'the',
#  'rest',
#  'of',
#  'my',
#  'life',
#  'just',
#  'sat',
#  'here',
#  'and',
#  'going',
#  'to',
#  'gig',
#  '.',
#  'seriously',
#  '.',
#  'Feeeling',
#  'like',
#  'shit',
#  'right',
#  'now',
#  '.',
#  'I',
#  'really',
#  'want',
#  'to',
#  'sleep',
#  ',',
#  'but',
#  'nooo',
#  'I',
#  'have',
#  '3',
#  'hour',
#  'of',
#  'dancing',
#  'and',
#  'an',
#  'art',
#  'assignment',
#  'to',
#  'finish',
#  '.',
#  'goodbye',
#  'exam',
#  ',',
#  'HELLO',
#  'ALCOHOL',
#  'TONIGHT',
#  'I',
#  'did',
#  "n't",
#  'realize',
#  'it',
#  'wa',
#  'THAT',
#  'deep',
#  '.',
#  'Geez',
#  'give',
#  'a',
#  'girl',
#  'a',
#  'warning',
#  'atleast',
#  '!',
#  'I',
#  'hate',
#  'it',
#  'when',
#  'any',
#  'athlete',
#  'appears',
#  'to',
#  'tear',
#  'an',
#  'ACL',
#  'on',
#  'live',
#  'television',
#  '.',
#  'i',
#  'miss',
#  'you',
#  'guy',
#  'too',
#  'i',
#  'think',
#  'i',
#  "'m",
#  'wearing',
#  'skinny',
#  'jean',
#  'a',
#  'cute',
#  'sweater',
#  'and',
#  'heel',
#  'not',
#  'really',
#  'sure',
#  'what',
#  'are',
#  'you',
#  'doing',
#  'today',
#  '--',
#  'Meet',
#  'your',
#  'Meat',
#  'http',
#  ':',
#  '//bit.ly/15SSCI',
#  'My',
#  'horsie',
#  'is',
#  'moving',
#  'on',
#  'Saturday',
#  'morning',
#  '.',
#  'No',
#  'Sat',
#  'off',
#  '...',
#  'Need',
#  'to',
#  'work',
#  '6',
#  'day',
#  'a',
#  'week',
#  'Really',
#  'Dont',
#  'Like',
#  'Doing',
#  'my',
#  'Room',
#  'Its',
#  'So',
#  'Boring',
#  'Sick',
#  'Of',
#  'Doing',
#  'My',
#  'Wardrobe',
#  'Out',
#  'Cant',
#  'Waiit',
#  'Till',
#  'I',
#  'Have',
#  'My',
#  'Walk',
#  'In',
#  'One',
#  'Yay',
#  'SOX',
#  '!',
#  'Floyd',
#  'wa',
#  'great',
#  ',',
#  'but',
#  'reliever',
#  'need',
#  'a',
#  'scolding',
#  '!',
#  'time',
#  'by',
#  'like',
#  'a',
#  'million',
#  'uploading',
#  'picture',
#  'on',
#  'friendster',
#  'what',
#  'type',
#  'of',
#  'a',
#  'spaz',
#  'downloads',
#  'a',
#  'virus',
#  '?',
#  'my',
#  'brother',
#  'that',
#  "'s",
#  'who',
#  ':',
#  '\\',
#  'MSN',
#  'is',
#  'now',
#  'fucked',
#  'forever',
#  ':',
#  "'",
#  '(',
#  '&',
#  'amp',
#  ';',
#  '&',
#  'amp',
#  ';',
#  'Fightiin',
#  'Wiit',
#  'The',
#  'Babes',
#  '...',
#  '(',
#  ':',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '-',
#  'so',
#  'i',
#  'wrote',
#  'something',
#  'last',
#  'week',
#  '.',
#  'and',
#  'i',
#  'got',
#  'a',
#  'call',
#  'from',
#  'someone',
#  'in',
#  'the',
#  'new',
#  'york',
#  'office',
#  '...',
#  'http',
#  ':',
#  '//tumblr.com/xcn21w6o7',
#  '*',
#  'enough',
#  'said',
#  '*',
#  '...',
#  'Do',
#  'I',
#  'need',
#  'to',
#  'even',
#  'say',
#  'it',
#  '?',
#  'Do',
#  'I',
#  '?',
#  'Well',
#  ',',
#  'here',
#  'I',
#  'go',
#  'anyways',
#  ':',
#  'CHRIS',
#  'CORNELL',
#  'IN',
#  'CHICAGO',
#  '!',
#  '...',
#  'TONIGHT',
#  '!',
#  '...',
#  'health',
#  'class',
#  '(',
#  'what',
#  'a',
#  'joke',
#  '!',
#  ')',
#  '@',
#  'ginaaa',
#  '&',
#  'lt',
#  ';',
#  '3',
#  'GO',
#  'TO',
#  'THE',
#  'SHOW',
#  'TONIGHT',
#  '@',
#  'Spiral_galaxy',
#  '@',
#  'YMPtweet',
#  'it',
#  'really',
#  'make',
#  'me',
#  'sad',
#  'when',
#  'i',
#  'look',
#  'at',
#  'Muslims',
#  'reality',
#  'now',
#  '-',
#  'All',
#  'Time',
#  'Low',
#  'shall',
#  'be',
#  'my',
#  'motivation',
#  'for',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'week',
#  '.',
#  'and',
#  'the',
#  'entertainment',
#  'is',
#  'over',
#  ',',
#  'someone',
#  'complained',
#  'properly',
#  '..',
#  '@',
#  'rupturerapture',
#  'experimental',
#  'you',
#  'say',
#  '?',
#  'he',
#  'should',
#  'experiment',
#  'with',
#  'a',
#  'melody',
#  'another',
#  'year',
#  'of',
#  'Lakers',
#  '..',
#  'That',
#  "'s",
#  'neither',
#  'magic',
#  'nor',
#  'fun',
#  '...',
#  'baddest',
#  'day',
#  'eveer',
#  '.',
#  'bathroom',
#  'is',
#  'clean',
#  '.....',
#  'now',
#  'on',
#  'to',
#  'more',
#  'enjoyable',
#  'task',
#  '......',
#  'boom',
#  'boom',
#  'pow',
#  'but',
#  'i',
#  "'m",
#  'proud',
#  '.',
#  'congrats',
#  'to',
#  'helio',
#  'though',
#  'David',
#  'must',
#  'be',
#  'hospitalized',
#  'for',
#  'five',
#  'day',
#  'end',
#  'of',
#  'July',
#  '(',
#  'palatine',
#  'tonsil',
#  ')',
#  '.',
#  'I',
#  'will',
#  'probably',
#  'never',
#  'see',
#  'Katie',
#  'in',
#  'concert',
#  '.',
#  'friend',
#  'are',
#  'leaving',
#  'me',
#  "'cause",
#  'of',
#  'this',
#  'stupid',
#  'love',
#  'http',
#  ':',
#  '//bit.ly/ZoxZC',
#  'go',
#  'give',
#  'ur',
#  'mom',
#  'a',
#  'hug',
#  'right',
#  'now',
#  '.',
#  'http',
#  ':',
#  '//bit.ly/azFwv',
#  'Going',
#  'To',
#  'See',
#  'Harry',
#  'Sunday',
#  'Happiness',
#  'Hand',
#  'quilting',
#  'it',
#  'is',
#  'then',
#  '...',
#  'hate',
#  'u',
#  '...',
#  'leysh',
#  't9ar5',
#  '...',
#  '=',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '..',
#  '=-',
#  'I',
#  'always',
#  'get',
#  'what',
#  'I',
#  'want',
#  'I',
#  'bend',
#  'backwards',
#  'i',
#  'get',
#  'off',
#  'work',
#  'sooooon',
#  '!',
#  'i',
#  'miss',
#  'cody',
#  'booo',
#  '.',
#  'have',
#  "n't",
#  'seen',
#  'him',
#  'in',
#  'foreverr',
#  '!',
#  'I',
#  'hate',
#  'allergy',
#  '.',
#  'Should',
#  'I',
#  'get',
#  'my',
#  'hair',
#  'cut',
#  'tomorrow',
#  '?',
#  'I',
#  "'m",
#  'taking',
#  'a',
#  'public',
#  'poll',
#  '...',
#  '-',
#  'I',
#  'love',
#  'you',
#  'guy',
#  'so',
#  'much',
#  'that',
#  'it',
#  'hurt',
#  '.',
#  'http',
#  ':',
#  '//tumblr.com/xkh1z19us',
#  'I',
#  'miss',
#  'Earl',
#  'I',
#  'miss',
#  'New',
#  'Jersey',
#  'I',
#  'missed',
#  'the',
#  'first',
#  'hour',
#  'of',
#  'SYTYCD',
#  'last',
#  'night',
#  ',',
#  'and',
#  'I',
#  'ca',
#  "n't",
#  'find',
#  'it',
#  'online',
#  '!',
#  'I',
#  'need',
#  'a',
#  'U2',
#  'fix',
#  'NOW',
#  '!',
#  'I',
#  'never',
#  'thought',
#  'I',
#  "'d",
#  'become',
#  'second',
#  'choice',
#  '...',
#  'I',
#  'think',
#  'I',
#  'may',
#  'be',
#  'too',
#  'friendly',
#  '...',
#  'lol',
#  '...',
#  'o',
#  'well',
#  '...',
#  'I',
#  'think',
#  'Manuel',
#  '(',
#  'my',
#  'Basil',
#  'plant',
#  ')',
#  'only',
#  'ha',
#  'day',
#  'to',
#  'live',
#  'I',
#  'wan',
#  'na',
#  'be',
#  'at',
#  'home',
#  '@',
#  'church',
#  '...',
#  'I',
#  'wonder',
#  'wht',
#  'they',
#  'are',
#  'doing',
#  '?',
#  'i',
#  'wan',
#  'na',
#  'make',
#  'my',
#  'own',
#  'pizza',
#  'i',
#  'want',
#  'a',
#  '120gb',
#  'harddrive',
#  ',',
#  'or',
#  'a',
#  '37',
#  'inch',
#  'tv',
#  ...]

# %%
#inserted later
lemmatize_tokenize(train_data.SentimentText.str.cat())
# Out:
# ['is',
#  'so',
#  'sad',
#  'for',
#  'my',
#  'APL',
#  'friend',
#  '.............',
#  'I',
#  'missed',
#  'the',
#  'New',
#  'Moon',
#  'trailer',
#  '...',
#  'omg',
#  'it',
#  'already',
#  '7:30',
#  ':',
#  'O',
#  '..',
#  'Omgaga',
#  '.',
#  'Im',
#  'sooo',
#  'im',
#  'gunna',
#  'CRy',
#  '.',
#  'I',
#  "'ve",
#  'been',
#  'at',
#  'this',
#  'dentist',
#  'since',
#  '11',
#  '..',
#  'I',
#  'wa',
#  'suposed',
#  '2',
#  'just',
#  'get',
#  'a',
#  'crown',
#  'put',
#  'on',
#  '(',
#  '30mins',
#  ')',
#  '...',
#  'i',
#  'think',
#  'mi',
#  'bf',
#  'is',
#  'cheating',
#  'on',
#  'me',
#  '!',
#  '!',
#  '!',
#  'T_T',
#  'or',
#  'i',
#  'just',
#  'worry',
#  'too',
#  'much',
#  '?',
#  'Juuuuuuuuuuuuuuuuussssst',
#  'Chillin',
#  '!',
#  '!',
#  'Sunny',
#  'Again',
#  'Work',
#  'Tomorrow',
#  ':',
#  '-|',
#  'TV',
#  'Tonight',
#  'handed',
#  'in',
#  'my',
#  'uniform',
#  'today',
#  '.',
#  'i',
#  'miss',
#  'you',
#  'already',
#  'hmmmm',
#  '....',
#  'i',
#  'wonder',
#  'how',
#  'she',
#  'my',
#  'number',
#  '@',
#  '-',
#  ')',
#  'I',
#  'must',
#  'think',
#  'about',
#  'positive',
#  '..',
#  'thanks',
#  'to',
#  'all',
#  'the',
#  'hater',
#  'up',
#  'in',
#  'my',
#  'face',
#  'all',
#  'day',
#  '!',
#  '112-102',
#  'this',
#  'weekend',
#  'ha',
#  'sucked',
#  'so',
#  'far',
#  'jb',
#  'isnt',
#  'showing',
#  'in',
#  'australia',
#  'any',
#  'more',
#  '!',
#  'ok',
#  'thats',
#  'it',
#  'you',
#  'win',
#  '.',
#  '&',
#  'lt',
#  ';',
#  '--',
#  '--',
#  '--',
#  '--',
#  'This',
#  'is',
#  'the',
#  'way',
#  'i',
#  'feel',
#  'right',
#  'now',
#  '...',
#  'awhhe',
#  'man',
#  '....',
#  'I',
#  "'m",
#  'completely',
#  'useless',
#  'rt',
#  'now',
#  '.',
#  'Funny',
#  ',',
#  'all',
#  'I',
#  'can',
#  'do',
#  'is',
#  'twitter',
#  '.',
#  'http',
#  ':',
#  '//myloc.me/27HX',
#  'Feeling',
#  'strangely',
#  'fine',
#  '.',
#  'Now',
#  'I',
#  "'m",
#  'gon',
#  'na',
#  'go',
#  'listen',
#  'to',
#  'some',
#  'Semisonic',
#  'to',
#  'celebrate',
#  'HUGE',
#  'roll',
#  'of',
#  'thunder',
#  'just',
#  'now',
#  '...',
#  'SO',
#  'scary',
#  '!',
#  '!',
#  '!',
#  '!',
#  'I',
#  'just',
#  'cut',
#  'my',
#  'beard',
#  'off',
#  '.',
#  'It',
#  "'s",
#  'only',
#  'been',
#  'growing',
#  'for',
#  'well',
#  'over',
#  'a',
#  'year',
#  '.',
#  'I',
#  "'m",
#  'gon',
#  'na',
#  'start',
#  'it',
#  'over',
#  '.',
#  '@',
#  'shaunamanu',
#  'is',
#  'happy',
#  'in',
#  'the',
#  'meantime',
#  '.',
#  'Very',
#  'sad',
#  'about',
#  'Iran',
#  '.',
#  'wompppp',
#  'wompp',
#  'You',
#  "'re",
#  'the',
#  'only',
#  'one',
#  'who',
#  'can',
#  'see',
#  'this',
#  'cause',
#  'no',
#  'one',
#  'else',
#  'is',
#  'following',
#  'me',
#  'this',
#  'is',
#  'for',
#  'you',
#  'because',
#  'you',
#  "'re",
#  'pretty',
#  'awesome',
#  '&',
#  'lt',
#  ';',
#  '--',
#  '-Sad',
#  'level',
#  'is',
#  '3',
#  '.',
#  'I',
#  'wa',
#  'writing',
#  'a',
#  'massive',
#  'blog',
#  'tweet',
#  'on',
#  'Myspace',
#  'and',
#  'my',
#  'comp',
#  'shut',
#  'down',
#  '.',
#  'Now',
#  'it',
#  "'s",
#  'all',
#  'lost',
#  '*',
#  'lay',
#  'in',
#  'fetal',
#  'position',
#  '*',
#  '...',
#  'Headed',
#  'to',
#  'Hospitol',
#  ':',
#  'Had',
#  'to',
#  'pull',
#  'out',
#  'of',
#  'the',
#  'Golf',
#  'Tourny',
#  'in',
#  '3rd',
#  'place',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  'I',
#  'Think',
#  'I',
#  'Re-Ripped',
#  'something',
#  '!',
#  '!',
#  '!',
#  'Yeah',
#  'THAT',
#  '!',
#  '!',
#  'BoRinG',
#  ')',
#  ':',
#  'whats',
#  'wrong',
#  'with',
#  'him',
#  '?',
#  '?',
#  'Please',
#  'tell',
#  'me',
#  '........',
#  ':',
#  '-/',
#  'ca',
#  "n't",
#  'be',
#  'bothered',
#  '.',
#  'i',
#  'wish',
#  'i',
#  'could',
#  'spend',
#  'the',
#  'rest',
#  'of',
#  'my',
#  'life',
#  'just',
#  'sat',
#  'here',
#  'and',
#  'going',
#  'to',
#  'gig',
#  '.',
#  'seriously',
#  '.',
#  'Feeeling',
#  'like',
#  'shit',
#  'right',
#  'now',
#  '.',
#  'I',
#  'really',
#  'want',
#  'to',
#  'sleep',
#  ',',
#  'but',
#  'nooo',
#  'I',
#  'have',
#  '3',
#  'hour',
#  'of',
#  'dancing',
#  'and',
#  'an',
#  'art',
#  'assignment',
#  'to',
#  'finish',
#  '.',
#  'goodbye',
#  'exam',
#  ',',
#  'HELLO',
#  'ALCOHOL',
#  'TONIGHT',
#  'I',
#  'did',
#  "n't",
#  'realize',
#  'it',
#  'wa',
#  'THAT',
#  'deep',
#  '.',
#  'Geez',
#  'give',
#  'a',
#  'girl',
#  'a',
#  'warning',
#  'atleast',
#  '!',
#  'I',
#  'hate',
#  'it',
#  'when',
#  'any',
#  'athlete',
#  'appears',
#  'to',
#  'tear',
#  'an',
#  'ACL',
#  'on',
#  'live',
#  'television',
#  '.',
#  'i',
#  'miss',
#  'you',
#  'guy',
#  'too',
#  'i',
#  'think',
#  'i',
#  "'m",
#  'wearing',
#  'skinny',
#  'jean',
#  'a',
#  'cute',
#  'sweater',
#  'and',
#  'heel',
#  'not',
#  'really',
#  'sure',
#  'what',
#  'are',
#  'you',
#  'doing',
#  'today',
#  '--',
#  'Meet',
#  'your',
#  'Meat',
#  'http',
#  ':',
#  '//bit.ly/15SSCI',
#  'My',
#  'horsie',
#  'is',
#  'moving',
#  'on',
#  'Saturday',
#  'morning',
#  '.',
#  'No',
#  'Sat',
#  'off',
#  '...',
#  'Need',
#  'to',
#  'work',
#  '6',
#  'day',
#  'a',
#  'week',
#  'Really',
#  'Dont',
#  'Like',
#  'Doing',
#  'my',
#  'Room',
#  'Its',
#  'So',
#  'Boring',
#  'Sick',
#  'Of',
#  'Doing',
#  'My',
#  'Wardrobe',
#  'Out',
#  'Cant',
#  'Waiit',
#  'Till',
#  'I',
#  'Have',
#  'My',
#  'Walk',
#  'In',
#  'One',
#  'Yay',
#  'SOX',
#  '!',
#  'Floyd',
#  'wa',
#  'great',
#  ',',
#  'but',
#  'reliever',
#  'need',
#  'a',
#  'scolding',
#  '!',
#  'time',
#  'by',
#  'like',
#  'a',
#  'million',
#  'uploading',
#  'picture',
#  'on',
#  'friendster',
#  'what',
#  'type',
#  'of',
#  'a',
#  'spaz',
#  'downloads',
#  'a',
#  'virus',
#  '?',
#  'my',
#  'brother',
#  'that',
#  "'s",
#  'who',
#  ':',
#  '\\',
#  'MSN',
#  'is',
#  'now',
#  'fucked',
#  'forever',
#  ':',
#  "'",
#  '(',
#  '&',
#  'amp',
#  ';',
#  '&',
#  'amp',
#  ';',
#  'Fightiin',
#  'Wiit',
#  'The',
#  'Babes',
#  '...',
#  '(',
#  ':',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '-',
#  'so',
#  'i',
#  'wrote',
#  'something',
#  'last',
#  'week',
#  '.',
#  'and',
#  'i',
#  'got',
#  'a',
#  'call',
#  'from',
#  'someone',
#  'in',
#  'the',
#  'new',
#  'york',
#  'office',
#  '...',
#  'http',
#  ':',
#  '//tumblr.com/xcn21w6o7',
#  '*',
#  'enough',
#  'said',
#  '*',
#  '...',
#  'Do',
#  'I',
#  'need',
#  'to',
#  'even',
#  'say',
#  'it',
#  '?',
#  'Do',
#  'I',
#  '?',
#  'Well',
#  ',',
#  'here',
#  'I',
#  'go',
#  'anyways',
#  ':',
#  'CHRIS',
#  'CORNELL',
#  'IN',
#  'CHICAGO',
#  '!',
#  '...',
#  'TONIGHT',
#  '!',
#  '...',
#  'health',
#  'class',
#  '(',
#  'what',
#  'a',
#  'joke',
#  '!',
#  ')',
#  '@',
#  'ginaaa',
#  '&',
#  'lt',
#  ';',
#  '3',
#  'GO',
#  'TO',
#  'THE',
#  'SHOW',
#  'TONIGHT',
#  '@',
#  'Spiral_galaxy',
#  '@',
#  'YMPtweet',
#  'it',
#  'really',
#  'make',
#  'me',
#  'sad',
#  'when',
#  'i',
#  'look',
#  'at',
#  'Muslims',
#  'reality',
#  'now',
#  '-',
#  'All',
#  'Time',
#  'Low',
#  'shall',
#  'be',
#  'my',
#  'motivation',
#  'for',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'week',
#  '.',
#  'and',
#  'the',
#  'entertainment',
#  'is',
#  'over',
#  ',',
#  'someone',
#  'complained',
#  'properly',
#  '..',
#  '@',
#  'rupturerapture',
#  'experimental',
#  'you',
#  'say',
#  '?',
#  'he',
#  'should',
#  'experiment',
#  'with',
#  'a',
#  'melody',
#  'another',
#  'year',
#  'of',
#  'Lakers',
#  '..',
#  'That',
#  "'s",
#  'neither',
#  'magic',
#  'nor',
#  'fun',
#  '...',
#  'baddest',
#  'day',
#  'eveer',
#  '.',
#  'bathroom',
#  'is',
#  'clean',
#  '.....',
#  'now',
#  'on',
#  'to',
#  'more',
#  'enjoyable',
#  'task',
#  '......',
#  'boom',
#  'boom',
#  'pow',
#  'but',
#  'i',
#  "'m",
#  'proud',
#  '.',
#  'congrats',
#  'to',
#  'helio',
#  'though',
#  'David',
#  'must',
#  'be',
#  'hospitalized',
#  'for',
#  'five',
#  'day',
#  'end',
#  'of',
#  'July',
#  '(',
#  'palatine',
#  'tonsil',
#  ')',
#  '.',
#  'I',
#  'will',
#  'probably',
#  'never',
#  'see',
#  'Katie',
#  'in',
#  'concert',
#  '.',
#  'friend',
#  'are',
#  'leaving',
#  'me',
#  "'cause",
#  'of',
#  'this',
#  'stupid',
#  'love',
#  'http',
#  ':',
#  '//bit.ly/ZoxZC',
#  'go',
#  'give',
#  'ur',
#  'mom',
#  'a',
#  'hug',
#  'right',
#  'now',
#  '.',
#  'http',
#  ':',
#  '//bit.ly/azFwv',
#  'Going',
#  'To',
#  'See',
#  'Harry',
#  'Sunday',
#  'Happiness',
#  'Hand',
#  'quilting',
#  'it',
#  'is',
#  'then',
#  '...',
#  'hate',
#  'u',
#  '...',
#  'leysh',
#  't9ar5',
#  '...',
#  '=',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '..',
#  '=-',
#  'I',
#  'always',
#  'get',
#  'what',
#  'I',
#  'want',
#  'I',
#  'bend',
#  'backwards',
#  'i',
#  'get',
#  'off',
#  'work',
#  'sooooon',
#  '!',
#  'i',
#  'miss',
#  'cody',
#  'booo',
#  '.',
#  'have',
#  "n't",
#  'seen',
#  'him',
#  'in',
#  'foreverr',
#  '!',
#  'I',
#  'hate',
#  'allergy',
#  '.',
#  'Should',
#  'I',
#  'get',
#  'my',
#  'hair',
#  'cut',
#  'tomorrow',
#  '?',
#  'I',
#  "'m",
#  'taking',
#  'a',
#  'public',
#  'poll',
#  '...',
#  '-',
#  'I',
#  'love',
#  'you',
#  'guy',
#  'so',
#  'much',
#  'that',
#  'it',
#  'hurt',
#  '.',
#  'http',
#  ':',
#  '//tumblr.com/xkh1z19us',
#  'I',
#  'miss',
#  'Earl',
#  'I',
#  'miss',
#  'New',
#  'Jersey',
#  'I',
#  'missed',
#  'the',
#  'first',
#  'hour',
#  'of',
#  'SYTYCD',
#  'last',
#  'night',
#  ',',
#  'and',
#  'I',
#  'ca',
#  "n't",
#  'find',
#  'it',
#  'online',
#  '!',
#  'I',
#  'need',
#  'a',
#  'U2',
#  'fix',
#  'NOW',
#  '!',
#  'I',
#  'never',
#  'thought',
#  'I',
#  "'d",
#  'become',
#  'second',
#  'choice',
#  '...',
#  'I',
#  'think',
#  'I',
#  'may',
#  'be',
#  'too',
#  'friendly',
#  '...',
#  'lol',
#  '...',
#  'o',
#  'well',
#  '...',
#  'I',
#  'think',
#  'Manuel',
#  '(',
#  'my',
#  'Basil',
#  'plant',
#  ')',
#  'only',
#  'ha',
#  'day',
#  'to',
#  'live',
#  'I',
#  'wan',
#  'na',
#  'be',
#  'at',
#  'home',
#  '@',
#  'church',
#  '...',
#  'I',
#  'wonder',
#  'wht',
#  'they',
#  'are',
#  'doing',
#  '?',
#  'i',
#  'wan',
#  'na',
#  'make',
#  'my',
#  'own',
#  'pizza',
#  'i',
#  'want',
#  'a',
#  '120gb',
#  'harddrive',
#  ',',
#  'or',
#  'a',
#  '37',
#  'inch',
#  'tv',
#  ...]

# %%
##inserted later
train_data.drop_duplicates(subset = 'SentimentText',keep = False, inplace = True)

# %%
##Inserted later
train_data['lemmatized_SentimentText'] = train_data['SentimentText'].apply(lambda x: lemmatize_tokenize(x))

# %%
##Inserted later
#train_data.lemmatized_SentimentText.str.cat()[:100]
revised_data = []
for i in train_data['lemmatized_SentimentText']:
    revised_data.append(i)

# %%
revised_data
# Out:
# [['is', 'so', 'sad', 'for', 'my', 'APL', 'friend', '.............'],
#  ['I', 'missed', 'the', 'New', 'Moon', 'trailer', '...'],
#  ['omg', 'it', 'already', '7:30', ':', 'O'],
#  ['..',
#   'Omgaga',
#   '.',
#   'Im',
#   'sooo',
#   'im',
#   'gunna',
#   'CRy',
#   '.',
#   'I',
#   "'ve",
#   'been',
#   'at',
#   'this',
#   'dentist',
#   'since',
#   '11',
#   '..',
#   'I',
#   'wa',
#   'suposed',
#   '2',
#   'just',
#   'get',
#   'a',
#   'crown',
#   'put',
#   'on',
#   '(',
#   '30mins',
#   ')',
#   '...'],
#  ['i',
#   'think',
#   'mi',
#   'bf',
#   'is',
#   'cheating',
#   'on',
#   'me',
#   '!',
#   '!',
#   '!',
#   'T_T'],
#  ['or', 'i', 'just', 'worry', 'too', 'much', '?'],
#  ['Juuuuuuuuuuuuuuuuussssst', 'Chillin', '!', '!'],
#  ['Sunny', 'Again', 'Work', 'Tomorrow', ':', '-|', 'TV', 'Tonight'],
#  ['handed',
#   'in',
#   'my',
#   'uniform',
#   'today',
#   '.',
#   'i',
#   'miss',
#   'you',
#   'already'],
#  ['hmmmm', '....', 'i', 'wonder', 'how', 'she', 'my', 'number', '@', '-', ')'],
#  ['I', 'must', 'think', 'about', 'positive', '..'],
#  ['thanks',
#   'to',
#   'all',
#   'the',
#   'hater',
#   'up',
#   'in',
#   'my',
#   'face',
#   'all',
#   'day',
#   '!',
#   '112-102'],
#  ['this', 'weekend', 'ha', 'sucked', 'so', 'far'],
#  ['jb', 'isnt', 'showing', 'in', 'australia', 'any', 'more', '!'],
#  ['ok', 'thats', 'it', 'you', 'win', '.'],
#  ['&',
#   'lt',
#   ';',
#   '--',
#   '--',
#   '--',
#   '--',
#   'This',
#   'is',
#   'the',
#   'way',
#   'i',
#   'feel',
#   'right',
#   'now',
#   '...'],
#  ['awhhe',
#   'man',
#   '....',
#   'I',
#   "'m",
#   'completely',
#   'useless',
#   'rt',
#   'now',
#   '.',
#   'Funny',
#   ',',
#   'all',
#   'I',
#   'can',
#   'do',
#   'is',
#   'twitter',
#   '.',
#   'http',
#   ':',
#   '//myloc.me/27HX'],
#  ['Feeling',
#   'strangely',
#   'fine',
#   '.',
#   'Now',
#   'I',
#   "'m",
#   'gon',
#   'na',
#   'go',
#   'listen',
#   'to',
#   'some',
#   'Semisonic',
#   'to',
#   'celebrate'],
#  ['HUGE',
#   'roll',
#   'of',
#   'thunder',
#   'just',
#   'now',
#   '...',
#   'SO',
#   'scary',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['I',
#   'just',
#   'cut',
#   'my',
#   'beard',
#   'off',
#   '.',
#   'It',
#   "'s",
#   'only',
#   'been',
#   'growing',
#   'for',
#   'well',
#   'over',
#   'a',
#   'year',
#   '.',
#   'I',
#   "'m",
#   'gon',
#   'na',
#   'start',
#   'it',
#   'over',
#   '.',
#   '@',
#   'shaunamanu',
#   'is',
#   'happy',
#   'in',
#   'the',
#   'meantime',
#   '.'],
#  ['Very', 'sad', 'about', 'Iran', '.'],
#  ['wompppp', 'wompp'],
#  ['You',
#   "'re",
#   'the',
#   'only',
#   'one',
#   'who',
#   'can',
#   'see',
#   'this',
#   'cause',
#   'no',
#   'one',
#   'else',
#   'is',
#   'following',
#   'me',
#   'this',
#   'is',
#   'for',
#   'you',
#   'because',
#   'you',
#   "'re",
#   'pretty',
#   'awesome'],
#  ['&',
#   'lt',
#   ';',
#   '--',
#   '-Sad',
#   'level',
#   'is',
#   '3',
#   '.',
#   'I',
#   'wa',
#   'writing',
#   'a',
#   'massive',
#   'blog',
#   'tweet',
#   'on',
#   'Myspace',
#   'and',
#   'my',
#   'comp',
#   'shut',
#   'down',
#   '.',
#   'Now',
#   'it',
#   "'s",
#   'all',
#   'lost',
#   '*',
#   'lay',
#   'in',
#   'fetal',
#   'position',
#   '*'],
#  ['...',
#   'Headed',
#   'to',
#   'Hospitol',
#   ':',
#   'Had',
#   'to',
#   'pull',
#   'out',
#   'of',
#   'the',
#   'Golf',
#   'Tourny',
#   'in',
#   '3rd',
#   'place',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'I',
#   'Think',
#   'I',
#   'Re-Ripped',
#   'something',
#   '!',
#   '!',
#   '!',
#   'Yeah',
#   'THAT',
#   '!',
#   '!'],
#  ['BoRinG',
#   ')',
#   ':',
#   'whats',
#   'wrong',
#   'with',
#   'him',
#   '?',
#   '?',
#   'Please',
#   'tell',
#   'me',
#   '........',
#   ':',
#   '-/'],
#  ['ca',
#   "n't",
#   'be',
#   'bothered',
#   '.',
#   'i',
#   'wish',
#   'i',
#   'could',
#   'spend',
#   'the',
#   'rest',
#   'of',
#   'my',
#   'life',
#   'just',
#   'sat',
#   'here',
#   'and',
#   'going',
#   'to',
#   'gig',
#   '.',
#   'seriously',
#   '.'],
#  ['Feeeling',
#   'like',
#   'shit',
#   'right',
#   'now',
#   '.',
#   'I',
#   'really',
#   'want',
#   'to',
#   'sleep',
#   ',',
#   'but',
#   'nooo',
#   'I',
#   'have',
#   '3',
#   'hour',
#   'of',
#   'dancing',
#   'and',
#   'an',
#   'art',
#   'assignment',
#   'to',
#   'finish',
#   '.'],
#  ['goodbye', 'exam', ',', 'HELLO', 'ALCOHOL', 'TONIGHT'],
#  ['I',
#   'did',
#   "n't",
#   'realize',
#   'it',
#   'wa',
#   'THAT',
#   'deep',
#   '.',
#   'Geez',
#   'give',
#   'a',
#   'girl',
#   'a',
#   'warning',
#   'atleast',
#   '!'],
#  ['I',
#   'hate',
#   'it',
#   'when',
#   'any',
#   'athlete',
#   'appears',
#   'to',
#   'tear',
#   'an',
#   'ACL',
#   'on',
#   'live',
#   'television',
#   '.'],
#  ['i',
#   'miss',
#   'you',
#   'guy',
#   'too',
#   'i',
#   'think',
#   'i',
#   "'m",
#   'wearing',
#   'skinny',
#   'jean',
#   'a',
#   'cute',
#   'sweater',
#   'and',
#   'heel',
#   'not',
#   'really',
#   'sure',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'today'],
#  ['--', 'Meet', 'your', 'Meat', 'http', ':', '//bit.ly/15SSCI'],
#  ['My', 'horsie', 'is', 'moving', 'on', 'Saturday', 'morning', '.'],
#  ['No', 'Sat', 'off', '...', 'Need', 'to', 'work', '6', 'day', 'a', 'week'],
#  ['Really',
#   'Dont',
#   'Like',
#   'Doing',
#   'my',
#   'Room',
#   'Its',
#   'So',
#   'Boring',
#   'Sick',
#   'Of',
#   'Doing',
#   'My',
#   'Wardrobe',
#   'Out',
#   'Cant',
#   'Waiit',
#   'Till',
#   'I',
#   'Have',
#   'My',
#   'Walk',
#   'In',
#   'One',
#   'Yay'],
#  ['SOX',
#   '!',
#   'Floyd',
#   'wa',
#   'great',
#   ',',
#   'but',
#   'reliever',
#   'need',
#   'a',
#   'scolding',
#   '!'],
#  ['time', 'by', 'like', 'a', 'million'],
#  ['uploading', 'picture', 'on', 'friendster'],
#  ['what',
#   'type',
#   'of',
#   'a',
#   'spaz',
#   'downloads',
#   'a',
#   'virus',
#   '?',
#   'my',
#   'brother',
#   'that',
#   "'s",
#   'who',
#   ':',
#   '\\',
#   'MSN',
#   'is',
#   'now',
#   'fucked',
#   'forever',
#   ':',
#   "'",
#   '('],
#  ['&', 'amp', ';', '&', 'amp', ';', 'Fightiin', 'Wiit', 'The', 'Babes', '...'],
#  ['(',
#   ':',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '-',
#   'so',
#   'i',
#   'wrote',
#   'something',
#   'last',
#   'week',
#   '.',
#   'and',
#   'i',
#   'got',
#   'a',
#   'call',
#   'from',
#   'someone',
#   'in',
#   'the',
#   'new',
#   'york',
#   'office',
#   '...',
#   'http',
#   ':',
#   '//tumblr.com/xcn21w6o7'],
#  ['*', 'enough', 'said', '*'],
#  ['...',
#   'Do',
#   'I',
#   'need',
#   'to',
#   'even',
#   'say',
#   'it',
#   '?',
#   'Do',
#   'I',
#   '?',
#   'Well',
#   ',',
#   'here',
#   'I',
#   'go',
#   'anyways',
#   ':',
#   'CHRIS',
#   'CORNELL',
#   'IN',
#   'CHICAGO',
#   '!',
#   '...',
#   'TONIGHT',
#   '!'],
#  ['...', 'health', 'class', '(', 'what', 'a', 'joke', '!', ')'],
#  ['@', 'ginaaa', '&', 'lt', ';', '3', 'GO', 'TO', 'THE', 'SHOW', 'TONIGHT'],
#  ['@',
#   'Spiral_galaxy',
#   '@',
#   'YMPtweet',
#   'it',
#   'really',
#   'make',
#   'me',
#   'sad',
#   'when',
#   'i',
#   'look',
#   'at',
#   'Muslims',
#   'reality',
#   'now'],
#  ['-',
#   'All',
#   'Time',
#   'Low',
#   'shall',
#   'be',
#   'my',
#   'motivation',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'week',
#   '.'],
#  ['and',
#   'the',
#   'entertainment',
#   'is',
#   'over',
#   ',',
#   'someone',
#   'complained',
#   'properly',
#   '..',
#   '@',
#   'rupturerapture',
#   'experimental',
#   'you',
#   'say',
#   '?',
#   'he',
#   'should',
#   'experiment',
#   'with',
#   'a',
#   'melody'],
#  ['another',
#   'year',
#   'of',
#   'Lakers',
#   '..',
#   'That',
#   "'s",
#   'neither',
#   'magic',
#   'nor',
#   'fun',
#   '...'],
#  ['baddest', 'day', 'eveer', '.'],
#  ['bathroom',
#   'is',
#   'clean',
#   '.....',
#   'now',
#   'on',
#   'to',
#   'more',
#   'enjoyable',
#   'task',
#   '......'],
#  ['boom', 'boom', 'pow'],
#  ['but', 'i', "'m", 'proud', '.'],
#  ['congrats', 'to', 'helio', 'though'],
#  ['David',
#   'must',
#   'be',
#   'hospitalized',
#   'for',
#   'five',
#   'day',
#   'end',
#   'of',
#   'July',
#   '(',
#   'palatine',
#   'tonsil',
#   ')',
#   '.',
#   'I',
#   'will',
#   'probably',
#   'never',
#   'see',
#   'Katie',
#   'in',
#   'concert',
#   '.'],
#  ['friend',
#   'are',
#   'leaving',
#   'me',
#   "'cause",
#   'of',
#   'this',
#   'stupid',
#   'love',
#   'http',
#   ':',
#   '//bit.ly/ZoxZC'],
#  ['go',
#   'give',
#   'ur',
#   'mom',
#   'a',
#   'hug',
#   'right',
#   'now',
#   '.',
#   'http',
#   ':',
#   '//bit.ly/azFwv'],
#  ['Going', 'To', 'See', 'Harry', 'Sunday', 'Happiness'],
#  ['Hand', 'quilting', 'it', 'is', 'then', '...'],
#  ['hate',
#   'u',
#   '...',
#   'leysh',
#   't9ar5',
#   '...',
#   '=',
#   '(',
#   '(',
#   '(',
#   '(',
#   '(',
#   '(',
#   '(',
#   '..'],
#  ['=-', 'I', 'always', 'get', 'what', 'I', 'want'],
#  ['I', 'bend', 'backwards'],
#  ['i',
#   'get',
#   'off',
#   'work',
#   'sooooon',
#   '!',
#   'i',
#   'miss',
#   'cody',
#   'booo',
#   '.',
#   'have',
#   "n't",
#   'seen',
#   'him',
#   'in',
#   'foreverr',
#   '!'],
#  ['I',
#   'hate',
#   'allergy',
#   '.',
#   'Should',
#   'I',
#   'get',
#   'my',
#   'hair',
#   'cut',
#   'tomorrow',
#   '?',
#   'I',
#   "'m",
#   'taking',
#   'a',
#   'public',
#   'poll',
#   '...'],
#  ['-',
#   'I',
#   'love',
#   'you',
#   'guy',
#   'so',
#   'much',
#   'that',
#   'it',
#   'hurt',
#   '.',
#   'http',
#   ':',
#   '//tumblr.com/xkh1z19us'],
#  ['I', 'miss', 'Earl'],
#  ['I', 'miss', 'New', 'Jersey'],
#  ['I',
#   'missed',
#   'the',
#   'first',
#   'hour',
#   'of',
#   'SYTYCD',
#   'last',
#   'night',
#   ',',
#   'and',
#   'I',
#   'ca',
#   "n't",
#   'find',
#   'it',
#   'online',
#   '!'],
#  ['I', 'need', 'a', 'U2', 'fix', 'NOW', '!'],
#  ['I', 'never', 'thought', 'I', "'d", 'become', 'second', 'choice', '...'],
#  ['I',
#   'think',
#   'I',
#   'may',
#   'be',
#   'too',
#   'friendly',
#   '...',
#   'lol',
#   '...',
#   'o',
#   'well',
#   '...'],
#  ['I',
#   'think',
#   'Manuel',
#   '(',
#   'my',
#   'Basil',
#   'plant',
#   ')',
#   'only',
#   'ha',
#   'day',
#   'to',
#   'live'],
#  ['I',
#   'wan',
#   'na',
#   'be',
#   'at',
#   'home',
#   '@',
#   'church',
#   '...',
#   'I',
#   'wonder',
#   'wht',
#   'they',
#   'are',
#   'doing',
#   '?'],
#  ['i', 'wan', 'na', 'make', 'my', 'own', 'pizza'],
#  ['i',
#   'want',
#   'a',
#   '120gb',
#   'harddrive',
#   ',',
#   'or',
#   'a',
#   '37',
#   'inch',
#   'tv',
#   ',',
#   'or',
#   'a',
#   'new',
#   'guitar',
#   '.',
#   'anyonefeeling',
#   'generous',
#   '?',
#   '=p',
#   'x'],
#  ['i', 'want', 'a', 'hug'],
#  ['I', 'want', 'Miley', 'to', 'tour', 'Australia'],
#  ['I',
#   'wanted',
#   'to',
#   'sleep',
#   'in',
#   'this',
#   'morning',
#   'but',
#   'a',
#   'mean',
#   'kid',
#   'through',
#   'a',
#   'popsicle',
#   'stick',
#   'at',
#   'me',
#   'head',
#   '.',
#   'I',
#   'wish',
#   'I',
#   'could',
#   'fly',
#   'away',
#   'like',
#   'those',
#   'squirrel'],
#  ['i', 'wa', 'too', 'slow', 'to', 'get', '$', '1', 'Up', 'tix'],
#  ['I',
#   'will',
#   'send',
#   'sunshine',
#   'to',
#   'Northern',
#   'Ireland',
#   ',',
#   'are',
#   'you',
#   'going',
#   'swimming',
#   'today',
#   '@',
#   'kezbat'],
#  ['I',
#   'wish',
#   'I',
#   'could',
#   'go',
#   'to',
#   'T4',
#   'On',
#   'The',
#   'Beach',
#   ':',
#   "'",
#   '(',
#   'Would',
#   'be',
#   'great',
#   'to',
#   'see',
#   '@',
#   'Shontelle_Layne',
#   '&',
#   'amp',
#   ';',
#   '@',
#   'DanMerriweather'],
#  ['i',
#   'would',
#   'be',
#   'so',
#   'much',
#   'happier',
#   'if',
#   'the',
#   'wall',
#   'of',
#   'my',
#   'bedroom',
#   'were',
#   'painted',
#   'white',
#   ','],
#  ['idk',
#   'wat',
#   '2',
#   'do',
#   'who',
#   'can',
#   'i',
#   'trust',
#   'me',
#   'im',
#   'sorry',
#   '4',
#   'all',
#   'da',
#   'pain',
#   'i',
#   'have',
#   'caused',
#   'nebody',
#   'ima',
#   'take',
#   'dis',
#   'time',
#   'out',
#   '2',
#   'straighten',
#   'myself',
#   'out',
#   'i',
#   'luv',
#   'yall'],
#  ['I',
#   "'m",
#   'finding',
#   'the',
#   'intercept',
#   'slope',
#   '..',
#   'and',
#   'banging',
#   'my',
#   'head',
#   'against',
#   'the',
#   'wall',
#   '..',
#   'Math',
#   'brain',
#   'head',
#   'come',
#   'save',
#   'me'],
#  ['I', "'m", 'really', 'going', 'to', 'bed', 'now', '...'],
#  ['im', 'sick', "'cough", 'cough', "'"],
#  ['in',
#   'cab',
#   'headed',
#   'to',
#   'the',
#   'airport',
#   '!',
#   'going',
#   'home',
#   '....',
#   '&',
#   'lt',
#   ';',
#   'christy',
#   '&',
#   'gt',
#   ';'],
#  ['In',
#   'case',
#   'I',
#   'feel',
#   'emo',
#   'in',
#   'camp',
#   '(',
#   'feeling',
#   'a',
#   'wee',
#   'bit',
#   'of',
#   'it',
#   'alr',
#   ')',
#   '...',
#   'am',
#   'bringing',
#   'in',
#   'the',
#   'Human',
#   'Rights',
#   'Watch',
#   'World',
#   'Report',
#   '2009',
#   '..',
#   'hope',
#   'it',
#   "'ll",
#   'work'],
#  ['Jin', 'ha', 'a', 'twitter', '.'],
#  ['jonas', 'day', 'is', 'almost', 'over', '...'],
#  ['Jus',
#   'Got',
#   'Hom',
#   'Fr',
#   '.',
#   'TDa',
#   'Funeral',
#   '...',
#   'I',
#   "'m",
#   'So',
#   'Sad',
#   '!',
#   'I',
#   'Cried',
#   'So',
#   'Much',
#   'Times',
#   '!',
#   'Much',
#   'Love',
#   'Grandpa',
#   '!',
#   '&',
#   'lt',
#   ';',
#   '3',
#   'I',
#   'Never',
#   'Got',
#   'To',
#   'Say',
#   'My',
#   'Last',
#   '&',
#   'quot',
#   ';',
#   'Goodbye',
#   '&',
#   'quot',
#   ';',
#   'to',
#   'Him',
#   '.'],
#  ['just',
#   'gon',
#   'na',
#   'smile',
#   '...',
#   'cuz',
#   'it',
#   'is',
#   'what',
#   'it',
#   'is',
#   '..',
#   'and',
#   'im',
#   'not',
#   'sure',
#   'what',
#   'more',
#   'they',
#   'could',
#   'want',
#   '..'],
#  ['Just',
#   'got',
#   'home',
#   ',',
#   'and',
#   'I',
#   'got',
#   'to',
#   'see',
#   'my',
#   'friend',
#   'Zahra',
#   'whom',
#   'I',
#   'have',
#   "n't",
#   'seen',
#   'since',
#   'We',
#   'graduated',
#   '!',
#   '!',
#   '!',
#   'That',
#   'make',
#   'me',
#   'so',
#   'happy',
#   '.'],
#  ['-',
#   'Longest',
#   'night',
#   'ever',
#   '..',
#   'ugh',
#   '!',
#   'http',
#   ':',
#   '//tumblr.com/xwp1yxhi6'],
#  ['mi',
#   'momacita',
#   'wo',
#   "n't",
#   'let',
#   'me',
#   'go',
#   'to',
#   'my',
#   'bf',
#   "'s",
#   'bball',
#   'game',
#   '!',
#   '!',
#   '!',
#   'grrr',
#   '!',
#   '!',
#   '!'],
#  ['Mom',
#   'say',
#   'I',
#   'have',
#   'to',
#   'get',
#   'a',
#   'new',
#   'phone',
#   'IMMEDIATELY',
#   '....',
#   'off',
#   'to',
#   'T-Mobile',
#   '.',
#   'she',
#   'paying',
#   '....'],
#  ['My',
#   'new',
#   'car',
#   'wa',
#   'stolen',
#   '....',
#   'by',
#   'my',
#   'mother',
#   'who',
#   'wanted',
#   'to',
#   'go',
#   'pose',
#   'at',
#   'church',
#   '.'],
#  ['no',
#   'hang',
#   'out',
#   'with',
#   'the',
#   'girl',
#   '2day',
#   '.',
#   '2moro',
#   ',',
#   'hope',
#   'so',
#   '......'],
#  ['no',
#   'movie',
#   'time',
#   'for',
#   'sunday',
#   '!',
#   'Rats',
#   'will',
#   'have',
#   'to',
#   'plan',
#   'tomorrow',
#   '.',
#   'I',
#   'guess',
#   'this',
#   'mean',
#   'I',
#   'have',
#   'to',
#   'work',
#   'on',
#   'those',
#   'two',
#   'presentation',
#   'I',
#   'am',
#   'doing',
#   '!'],
#  ['no', 'pavel', 'tonight', '&', 'lt', ';', 'Tigersfan', '&', 'gt', ';'],
#  ['not', 'a', 'cool', 'night', '.'],
#  ['oh', 'thank', 'you', '!'],
#  ['pleased'],
#  ['probably',
#   'guna',
#   'get',
#   'off',
#   'soon',
#   'since',
#   'no',
#   'one',
#   'is',
#   'talkin',
#   'no',
#   'more'],
#  ['really',
#   'wanted',
#   'Safina',
#   'to',
#   'pull',
#   'out',
#   'a',
#   'win',
#   '&',
#   'amp',
#   ';',
#   'to',
#   'lose',
#   'like',
#   'that',
#   '...'],
#  ['RIP', ',', 'David', 'Eddings', '.'],
#  ['Rose',
#   'and',
#   'ood',
#   'will',
#   'be',
#   'back',
#   'in',
#   'the',
#   'Xmas',
#   'Who',
#   'special',
#   '!',
#   'YAY',
#   '!',
#   'Damn',
#   'that',
#   "'s",
#   'half',
#   'a',
#   'year',
#   'away',
#   '.'],
#  ['-',
#   'sannesias',
#   ':',
#   'Aww',
#   'no',
#   'neighbor',
#   '!',
#   'We',
#   'need',
#   'to',
#   'watch',
#   'Mean',
#   'Girls',
#   ':',
#   ']',
#   'http',
#   ':',
#   '//tumblr.com/xv31s2pi8'],
#  ['so', 'whats', 'the', 'status', 'on', 'next', 'weekend'],
#  ['sorry',
#   '@',
#   'gigi4462',
#   'The',
#   'Ex',
#   'Husband',
#   'ha',
#   'overdosed',
#   'on',
#   'his',
#   'daily',
#   'dose',
#   'of',
#   'haterade'],
#  ['Thanks',
#   'for',
#   'your',
#   'definition',
#   'of',
#   'throwbie',
#   '!',
#   'Editors',
#   'reviewed',
#   'your',
#   'entry',
#   'and',
#   'have',
#   'decided',
#   'to',
#   'not',
#   'publish',
#   'it',
#   '.'],
#  ['Thanks', ',', 'I', 'need', 'all', 'the', 'help', 'i', 'can', 'get', '.'],
#  ['-', 'that', 'explains', 'alot', '.'],
#  ['There',
#   "'s",
#   'going',
#   'to',
#   'be',
#   'a',
#   'Heathers',
#   'sequel',
#   '.',
#   'Winona4ever',
#   '!',
#   'They',
#   'better',
#   'not',
#   'fuck',
#   'it',
#   'up',
#   '.'],
#  ['told',
#   'not',
#   'to',
#   'drink',
#   'w/my',
#   'Rx',
#   'so',
#   'just',
#   'gave',
#   'all',
#   'the',
#   'b.b',
#   '.',
#   'porter',
#   '&',
#   'amp',
#   ';',
#   'ob',
#   '.',
#   'stout',
#   'that',
#   'I',
#   'brought',
#   'home',
#   'from',
#   'OR',
#   'to',
#   'my',
#   'neighbor',
#   '.',
#   'v',
#   ',',
#   'v',
#   ',',
#   'sad',
#   '.'],
#  ['trae',
#   'is',
#   'so',
#   'sweet',
#   '!',
#   'He',
#   'just',
#   'bought',
#   'me',
#   'a',
#   'new',
#   'baithing',
#   'suit',
#   '!',
#   '!',
#   'Wove',
#   'him'],
#  ['True',
#   ',',
#   'highly',
#   'subjective',
#   'of',
#   'me',
#   'there',
#   '.',
#   'Tombre',
#   'wa',
#   'actually',
#   'my',
#   'favorite',
#   'character',
#   'in',
#   'the',
#   'book',
#   '.',
#   'You',
#   'got',
#   'me',
#   '-',
#   'http',
#   ':',
#   '//is.gd/13be0',
#   '-',
#   'Rishabh'],
#  ['u', 'guy', 'knw', 'whyy'],
#  ['very', 'much', 'so'],
#  ['waahhh',
#   'now',
#   'I',
#   "'m",
#   'getting',
#   'sad',
#   '....',
#   'miss',
#   'hub',
#   ':',
#   '-',
#   "'",
#   '(',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';'],
#  ['--',
#   'we',
#   'were',
#   'standing',
#   'out',
#   'in',
#   'the',
#   'pouring',
#   'rain',
#   '..',
#   'We',
#   'were',
#   'sitting',
#   'on',
#   'top',
#   'of',
#   'the',
#   'world',
#   '..',
#   '--',
#   'summer',
#   'suck',
#   '--'],
#  ['Went',
#   'to',
#   'get',
#   'dog',
#   'from',
#   'vet',
#   ',',
#   'theyve',
#   'stitched',
#   'her',
#   'ear',
#   ',',
#   'charged',
#   'u',
#   'for',
#   'it',
#   'but',
#   'she',
#   'still',
#   'bleeds',
#   'like',
#   'a',
#   'waterfall',
#   'everytime',
#   'she',
#   'move',
#   '.',
#   'D',
#   ':',
#   'WHY',
#   '!'],
#  ['where', 'is', 'my', 'picture', 'i', 'feel', 'naked'],
#  ['Why',
#   'are',
#   "n't",
#   'there',
#   'any',
#   'train',
#   'going',
#   'to',
#   'manchester',
#   'on',
#   'a',
#   'sunday',
#   '?',
#   '!',
#   '!',
#   'Now',
#   'I',
#   'ca',
#   "n't",
#   'go',
#   'to',
#   'the',
#   '@',
#   'jonasbrothers',
#   'concert',
#   '.'],
#  ['-',
#   'Why',
#   'must',
#   'people',
#   'be',
#   'so',
#   'picky',
#   '.',
#   'I',
#   'mean',
#   '6',
#   'hour',
#   'work',
#   'and',
#   'no',
#   'dice',
#   '!',
#   '?',
#   'whatï¿½s',
#   'up',
#   'with',
#   'that',
#   '!',
#   'http',
#   ':',
#   '//tumblr.com/xsg1m3ufn'],
#  ['Why',
#   'Twitter',
#   'will',
#   'soon',
#   'become',
#   'obsolete',
#   '?',
#   'http',
#   ':',
#   '//www.imediaconnection.com/content/23465.asp'],
#  ['wide', 'awake', 'NOT', '!', '!', '!'],
#  ['yeah',
#   'me',
#   'too',
#   '.',
#   'Its',
#   'been',
#   'awful',
#   'weather',
#   'here',
#   'for',
#   'the',
#   'last',
#   'week',
#   'so',
#   'that',
#   'stink',
#   '.',
#   'Kristis',
#   'comin',
#   'down',
#   'and',
#   'moe',
#   'said',
#   'mmmaybe',
#   'he',
#   'take',
#   'u',
#   'for',
#   '...'],
#  ['-',
#   'You',
#   ':',
#   'hi',
#   'Stranger',
#   ':',
#   'HELLO',
#   'I',
#   'AM',
#   'FRANK',
#   'LAMPARD',
#   'HOW',
#   'ARE',
#   'YOU',
#   'You',
#   ':',
#   'fine',
#   'You',
#   ':',
#   'and',
#   'urself',
#   'Stranger',
#   ':',
#   'i',
#   'am',
#   'gay',
#   'Your',
#   '...',
#   'http',
#   ':',
#   '//tumblr.com/xaj24dkly'],
#  ['you',
#   "'ll",
#   'always',
#   'be',
#   'my',
#   'one',
#   'and',
#   'only',
#   '...',
#   '[',
#   '12',
#   '*',
#   '23',
#   '*',
#   '2007',
#   ']'],
#  ['#', '3turnoffwords', 'this', 'shit', 'suck'],
#  ['#',
#   'asylm',
#   'J2',
#   'panel',
#   'is',
#   'over',
#   '.',
#   'Guess',
#   'it',
#   "'s",
#   'back',
#   'to',
#   'normal',
#   'life',
#   '.'],
#  ['#', 'poemsunder140', '....', 'started', 'by', '@', 'shannonelyse1'],
#  ['#',
#   'squarespace',
#   'brighten',
#   'my',
#   'bad',
#   'day',
#   '!',
#   'i',
#   'never',
#   'win',
#   'anything',
#   '...'],
#  ['#',
#   'Susan',
#   'Boyle',
#   'didnt',
#   'win',
#   '!',
#   'mh',
#   'well',
#   ',',
#   'diversity',
#   'wa',
#   'very',
#   'good',
#   'though',
#   '!',
#   'CONGRATZ',
#   '!',
#   '!'],
#  ['#', 'twenty20'],
#  ['&',
#   'lt',
#   ';',
#   '--',
#   '-',
#   'That',
#   'is',
#   'all',
#   ',',
#   'and',
#   'believe',
#   'me',
#   '..',
#   'it',
#   "'s",
#   'enough',
#   '!'],
#  ['&', 'lt', ';', '3', 'goooood', 'times'],
#  ['&', 'lt', ';', '3', 'GrAdUaTE', '09', '&', 'lt', ';', '3'],
#  ['&',
#   'quot',
#   ';',
#   'Vandals',
#   'paint',
#   'swastika',
#   'on',
#   'home',
#   'of',
#   'author',
#   'of',
#   'gay',
#   ',',
#   'lesbian',
#   'church',
#   'story',
#   ':',
#   'Naples',
#   'Daily',
#   'News',
#   '&',
#   'quot',
#   ';',
#   '(',
#   'http',
#   ':',
#   '//bit.ly/11zyzl',
#   ')'],
#  ['&',
#   'quot',
#   ';',
#   'An',
#   'unknown',
#   'error',
#   'occured',
#   '(',
#   '-4',
#   ')',
#   '&',
#   'quot',
#   ';',
#   '.',
#   'uh',
#   'oh',
#   '.',
#   'iPhone',
#   'OS',
#   '3',
#   'fail',
#   'so',
#   'far'],
#  ['&',
#   'quot',
#   ';',
#   'expert',
#   '(',
#   'homer',
#   ')',
#   'predict',
#   'Eagles',
#   'to',
#   'go',
#   '12-4',
#   'and',
#   'Giants',
#   'to',
#   'go',
#   '9-7/',
#   'BS',
#   '!',
#   'http',
#   ':',
#   '//www.dailysportspages.com/forums/showthread.php',
#   '?',
#   't=49343'],
#  ['&',
#   'quot',
#   ';',
#   'I',
#   'know',
#   'you',
#   'hungry',
#   'so',
#   'let',
#   'go',
#   'outside',
#   'on',
#   'the',
#   'balcony',
#   'so',
#   'you',
#   'can',
#   'eat',
#   '&',
#   'quot',
#   ';',
#   '....'],
#  ['&',
#   'quot',
#   ';',
#   'I',
#   'want',
#   'you',
#   'so',
#   'bad',
#   'it',
#   "'s",
#   'driving',
#   'me',
#   'mad',
#   '&',
#   'quot',
#   ';'],
#  ['&',
#   'quot',
#   ';',
#   'The',
#   '10',
#   'Men',
#   'a',
#   'UK',
#   'Female',
#   'Internet',
#   'Entrepreneur',
#   'Should',
#   'Know',
#   'when',
#   'Starting',
#   'and',
#   'Growing',
#   'a',
#   'Business',
#   ':',
#   'The',
#   'Next',
#   'Women',
#   '&',
#   'quot',
#   ';',
#   '(',
#   'http',
#   ':',
#   '//tinyurl.com',
#   '...'],
#  ['&',
#   'quot',
#   ';',
#   'The',
#   'truth',
#   'is',
#   'hiding',
#   'in',
#   'your',
#   'eye',
#   '&',
#   'quot',
#   ';',
#   '@',
#   'patita',
#   '@',
#   'MissMarian',
#   'Paramore',
#   'ï¿½',
#   'Decode',
#   '@',
#   'Daninho502',
#   '?',
#   'http',
#   ':',
#   '//blip.fm/~5ytke'],
#  ['&',
#   'quot',
#   ';',
#   'Try',
#   'to',
#   'turn',
#   'on',
#   'my',
#   'tv',
#   'to',
#   'get',
#   'you',
#   'out',
#   'of',
#   'my',
#   'head',
#   '.',
#   'I',
#   "'ve",
#   'got',
#   'this',
#   'feeling',
#   'inside',
#   'that',
#   'I',
#   'just',
#   'wo',
#   "n't",
#   'admit',
#   '...',
#   '&',
#   'quot',
#   ';',
#   '(',
#   'that',
#   'is',
#   'literally',
#   'how',
#   'I',
#   'feel',
#   ')'],
#  ['&',
#   'quot',
#   ';',
#   'well',
#   ',',
#   'the',
#   'truth',
#   'is',
#   'I',
#   'miss',
#   'you',
#   'so',
#   '&',
#   'quot',
#   ';',
#   '-',
#   'Coldplay'],
#  ['(',
#   'tear',
#   ')',
#   ':',
#   "'-",
#   '(',
#   'Today',
#   'is',
#   'the',
#   'last',
#   'day',
#   'with',
#   'my',
#   'kid',
#   '...',
#   'They',
#   'go',
#   'on',
#   'summer',
#   'break',
#   'at',
#   'their',
#   'Dads',
#   'tomorrow',
#   '.',
#   '*',
#   'sigh',
#   '*',
#   'http',
#   ':',
#   '//plurk.com/p/x8j86'],
#  ['(',
#   'unsure',
#   ')',
#   '(',
#   'annoyed',
#   ')',
#   'http',
#   ':',
#   '//plurk.com/p/1230lz'],
#  ['(',
#   'via',
#   '@',
#   'designrelated',
#   ')',
#   'are',
#   'designed',
#   'gallery',
#   'exhibition',
#   'postcards/mailers',
#   'going',
#   'extinct',
#   '?',
#   'via',
#   'NYT',
#   'http',
#   ':',
#   '//ow.ly/fHJc'],
#  ['*', 'BeautifulyLost'],
#  ['-',
#   '*',
#   'cry',
#   '*',
#   'I',
#   "'m",
#   'going',
#   'to',
#   'miss',
#   'Harry',
#   'Potter',
#   'when',
#   'it',
#   'come',
#   'out',
#   '.',
#   'I',
#   "'m",
#   'leaving',
#   'to',
#   'Vietnam',
#   'on',
#   'July',
#   '11th',
#   '.',
#   'I',
#   "'m",
#   'going',
#   'to',
#   'cry',
#   '!',
#   '!'],
#  ['--',
#   '*',
#   'hummin',
#   '*',
#   'I',
#   'SAY',
#   '&',
#   'quot',
#   ';',
#   'shut',
#   'up',
#   '&',
#   'amp',
#   ';',
#   'put',
#   'your',
#   'money',
#   'where',
#   'your',
#   'mouth',
#   'is',
#   '&',
#   'quot',
#   ';',
#   '...',
#   'headin',
#   "'",
#   'out',
#   'to',
#   'reality',
#   '.',
#   'Cheers',
#   'Twitter',
#   'world',
#   '!'],
#  ['--',
#   '.',
#   '*',
#   'sigh',
#   '*',
#   'You',
#   'cant',
#   'love',
#   'someone',
#   'that',
#   'doe',
#   "n't",
#   'love',
#   'you',
#   'back',
#   'that',
#   "'s",
#   'like',
#   'stalker',
#   'status',
#   '.',
#   'GET',
#   'a',
#   'divorce',
#   '&',
#   'amp',
#   ';',
#   '&',
#   'amp',
#   ';',
#   'move',
#   'on',
#   '.',
#   'Trinity',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   'going',
#   'back',
#   'to',
#   'bed',
#   ',',
#   'because',
#   'I',
#   "'m",
#   'lookin',
#   "'",
#   'around',
#   'and',
#   'do',
#   "n't",
#   'see',
#   'a',
#   'reason',
#   'to',
#   'be',
#   'awake',
#   'atm',
#   '.',
#   'Be',
#   'up',
#   'in',
#   'a',
#   'little',
#   '.'],
#  ['--',
#   '.',
#   'Aiqht',
#   'Goodniqht',
#   '.',
#   'Tri',
#   ',',
#   'Neena',
#   ',',
#   'Malcolm',
#   ',',
#   'Chaise',
#   ',',
#   'JLew',
#   ',',
#   'ATL',
#   '&',
#   'lt',
#   ';',
#   '333',
#   'Love',
#   'Much',
#   '.'],
#  ['--',
#   '.',
#   'Triiiiiii',
#   '.',
#   'ily',
#   '.',
#   'even',
#   'if',
#   'Chaise',
#   'doe',
#   "n't",
#   '.',
#   '=D',
#   '*',
#   'dy',
#   'of',
#   'laughter',
#   '*'],
#  ['..', 'i', 'wantt', 'hiim', 'soo', 'badd', '!', '!'],
#  ['..',
#   'watching',
#   'tv',
#   ',',
#   'bed',
#   ',',
#   'shopping',
#   'w.',
#   'mom',
#   ',',
#   'out',
#   'w.',
#   'trent',
#   'hopefully',
#   ',',
#   'i',
#   'need',
#   'my',
#   'best',
#   'friend'],
#  ['...',
#   'had',
#   'weird',
#   'encounter',
#   'with',
#   'so',
#   'many',
#   'homeless/creeps',
#   'on',
#   'the',
#   'walk',
#   'home',
#   'tonight',
#   'all',
#   'by',
#   'myself',
#   'awesome',
#   '...',
#   'really',
#   '...'],
#  ['...', 'Rained', 'out', 'truck', 'race'],
#  ['...',
#   'Why',
#   'am',
#   'I',
#   'feeling',
#   'worse',
#   '?',
#   '?',
#   '?',
#   'F',
#   '!',
#   '!',
#   '!'],
#  ['....',
#   'Feeling',
#   'pain',
#   'and',
#   'happiness',
#   'at',
#   'the',
#   'same',
#   'time',
#   '.',
#   'How',
#   'confusing',
#   '!'],
#  ['.....', 'hot', 'choco', 'is', 'the', 'best', '!'],
#  ['....', 'in', 'a', 'shirt', 'and', 'panty', '.', 'celulite'],
#  ['..',
#   'had',
#   'to',
#   'turn',
#   'back',
#   'to',
#   'North',
#   'due',
#   'to',
#   'body',
#   'on',
#   'line',
#   '.',
#   'So',
#   'missing',
#   'Design',
#   'Council',
#   'Design',
#   '4',
#   'Tech',
#   'Transfer',
#   'event',
#   'http',
#   ':',
#   '//bit.ly/pXrzV',
#   '...'],
#  ['..', 'y', 'everything', 'is', 'so', 'hard', '?', ':', '/'],
#  ['.bueno', 'good', 'bye', '.', 'good', 'night'],
#  [':',
#   'Beach',
#   'day',
#   'with',
#   'Scoobs',
#   '.',
#   '=',
#   '(',
#   ':',
#   'Still',
#   'no',
#   'phone',
#   '.'],
#  [':',
#   'Let',
#   "'s",
#   'have',
#   'fun',
#   ',',
#   '.',
#   'When',
#   'I',
#   'give',
#   'ya',
#   'what',
#   'I',
#   'give',
#   'ya',
#   '.'],
#  [':', '[', 'I', 'do', "n't", 'want', 'to', 'move', '!', '!', '!'],
#  [':',
#   '-D',
#   ')',
#   ')',
#   ')',
#   ')',
#   ')',
#   ')',
#   ')',
#   ')',
#   '...',
#   'WHAT',
#   'AN',
#   'AMAZING',
#   'NIGHT',
#   ',',
#   'DAY',
#   '&',
#   'amp',
#   ';',
#   'NIGHT',
#   'AGAIN',
#   '!',
#   '!',
#   'HI',
#   'TWITS',
#   '!',
#   'I',
#   'MiSS',
#   'U',
#   'GUYS'],
#  ['@', 'canaveral', 'national', 'seashore'],
#  ['@',
#   'progressing',
#   'in',
#   'the',
#   'production',
#   'department',
#   'with',
#   '&',
#   'quot',
#   ';',
#   'The',
#   'Uprizing',
#   '&',
#   'quot',
#   ';',
#   'thats',
#   'the',
#   'priority',
#   'getting',
#   'the',
#   'head',
#   'nodding',
#   'beat',
#   'and',
#   'then',
#   'we',
#   'reach',
#   'out'],
#  ['@',
#   'taylorrhicks',
#   'enjoy',
#   'chicago',
#   '..',
#   'b',
#   'new',
#   'venue',
#   'is',
#   'always',
#   'cool',
#   '.',
#   'You',
#   'shine',
#   'everywhere',
#   'you',
#   'go',
#   '.',
#   'I',
#   'know',
#   'who',
#   'you',
#   'are',
#   '.',
#   'In',
#   'time',
#   'so',
#   'will',
#   'everyone',
#   '.'],
#  ['@', 'the', 'train', 'crash', 'in', 'DC', '.....'],
#  ["'", '@', 'Thestreetforce', "'"],
#  ['@', '3sixty5days', 'make', 'me', 'smile', '.'],
#  ['@',
#   'adamisacson',
#   'My',
#   'first',
#   'day',
#   'off',
#   'in',
#   '3',
#   'week',
#   ',',
#   'and',
#   'my',
#   'child',
#   'got',
#   'up',
#   'before',
#   '7:00',
#   '.',
#   'So',
#   'watch',
#   'for',
#   'me',
#   'on',
#   '&',
#   'quot',
#   ';',
#   'Nancy',
#   'Grac',
#   '..',
#   'http',
#   ':',
#   '//tr.im/khKW'],
#  ['@',
#   'adbert',
#   ':',
#   '&',
#   'quot',
#   ';',
#   '#',
#   'Video',
#   '[',
#   'Woody',
#   'Woodpecker',
#   'â\x80\x93',
#   'The',
#   'Barber',
#   'of',
#   'Seville',
#   ']',
#   'I',
#   'am',
#   'great',
#   ',',
#   '@',
#   'klitoria',
#   ',',
#   'just',
#   'wishing',
#   'to',
#   'be',
#   'a',
#   'ch',
#   '...',
#   'â\x99',
#   '«',
#   'http',
#   ':',
#   '//blip.fm/~7g6r0'],
#  ['@',
#   'alexrauchman',
#   'I',
#   'am',
#   'happy',
#   'you',
#   'are',
#   'staying',
#   'around',
#   'here',
#   '.',
#   'Drexel',
#   'is',
#   'a',
#   'fabulous',
#   'university',
#   '.',
#   'You',
#   'should',
#   'be',
#   'proud',
#   '.',
#   'yeah',
#   '.'],
#  ['@',
#   'alvinkschneider',
#   'what',
#   'happened',
#   'to',
#   'angel',
#   'and',
#   'demon',
#   'and',
#   'lion',
#   'and',
#   'tiger',
#   'and',
#   'bear',
#   '!',
#   '?'],
#  ['@',
#   'AmericanWomannn',
#   'Well',
#   'that',
#   'sure',
#   'minimizes',
#   'the',
#   'impact',
#   '...',
#   'LOL'],
#  ['@',
#   'ange_black',
#   '@',
#   'sween',
#   'I',
#   'call',
#   'dibs',
#   'on',
#   'the',
#   'Voltron',
#   'arm',
#   '.',
#   'No',
#   'the',
#   'leg',
#   '.',
#   'Wait',
#   '.',
#   'Where',
#   'are',
#   'my',
#   'manner',
#   '?',
#   '@',
#   'baileygenine',
#   ',',
#   '..',
#   'http',
#   ':',
#   '//tr.im/oERy'],
#  ['@', 'CharlottegC', 'I', 'just', 'saw', 'ur', 'mum'],
#  ['@',
#   'chloelunn',
#   'and',
#   '@',
#   'meganmcdowell',
#   'GET',
#   'YOUR',
#   'FAT',
#   'ASSES',
#   'ON',
#   'HERE',
#   '.',
#   'NAI',
#   '.'],
#  ['-',
#   '@',
#   'codinghorror',
#   'See',
#   ',',
#   'three',
#   'external',
#   'monitor',
#   'on',
#   'one',
#   'laptop',
#   ',',
#   'http',
#   ':',
#   '//www.twitpic.com/6e3zp',
#   'Win7RC',
#   '1',
#   'x',
#   '1920x1080',
#   ',',
#   '2',
#   'x',
#   '1280x1024'],
#  ['@',
#   'copicmarker',
#   '&',
#   'quot',
#   ';',
#   'facebook.com/copic.marker',
#   'if',
#   'you',
#   "'re",
#   'cool',
#   '.',
#   'Or',
#   'if',
#   'you',
#   "'re",
#   'not',
#   'cool',
#   '.',
#   'Maybe',
#   'I',
#   "'ll",
#   'send',
#   'some',
#   'cool',
#   '..',
#   'http',
#   ':',
#   '//tr.im/oyT7'],
#  ["'",
#   '@',
#   'crewislife',
#   'you',
#   'want',
#   'to',
#   'start',
#   'the',
#   'morning',
#   'later',
#   ';',
#   'in',
#   'New',
#   'York',
#   'we',
#   'can',
#   'do',
#   'that',
#   '(',
#   'Californians',
#   'have',
#   'it',
#   'even',
#   'better',
#   ')'],
#  ['@',
#   'cybervenus',
#   'http',
#   ':',
#   '//twitpic.com/75kwb',
#   '~',
#   'LOL',
#   'LuV',
#   'IT',
#   '!',
#   '&',
#   'gt',
#   ';',
#   '&',
#   'gt',
#   ';',
#   'http',
#   ':',
#   '//twitpic.com/75hsg',
#   'Did',
#   'any1',
#   'find',
#   'or',
#   'c',
#   '1',
#   '?',
#   '#',
#   'a',
#   '..',
#   'http',
#   ':',
#   '//bit.ly/mUMFh'],
#  ['@',
#   'dandelionas',
#   'is',
#   'making',
#   'fettucini',
#   'and',
#   'garlic',
#   'bread',
#   '!'],
#  ['@',
#   'danregal',
#   'tell',
#   '@',
#   'pfont',
#   'i',
#   'said',
#   'Happy',
#   'BDay',
#   '!',
#   '!'],
#  ['-',
#   '@',
#   'Darcy_Lussier',
#   '@',
#   'lkrammes',
#   'I',
#   'went',
#   'to',
#   'work',
#   'once',
#   'last',
#   'year',
#   'with',
#   'no',
#   'pant',
#   '.',
#   'Ironically',
#   ',',
#   'that',
#   'wa',
#   'my',
#   'last',
#   'day',
#   'of',
#   'work',
#   'at',
#   'that',
#   'job',
#   '.',
#   'FML'],
#  ['@',
#   'DirtyRose17',
#   'told',
#   'you',
#   ',',
#   'you',
#   'would',
#   'sweep',
#   'haha',
#   ':',
#   '-p'],
#  ['@',
#   'dreamingspires',
#   '.',
#   'there',
#   'r',
#   'many',
#   'gr8',
#   'science',
#   'cartoon',
#   'http',
#   ':',
#   '//bit.ly/6EW4Q',
#   'http',
#   ':',
#   '//bit.ly/gXH3q',
#   'http',
#   ':',
#   '//bit.ly/18sjXI',
#   'http',
#   ':',
#   '//bit.ly/KEAy2'],
#  ['-',
#   '@',
#   'Em91',
#   'Edinburgh',
#   'fringe',
#   'is',
#   'only',
#   '10',
#   'week',
#   'away',
#   '?',
#   '!',
#   'I',
#   'need',
#   'monies',
#   'Btw',
#   'I',
#   "'m",
#   'Elliott',
#   'from',
#   '@',
#   'angryfeet',
#   '-',
#   'blame',
#   '@',
#   'howlieT',
#   'for',
#   'the',
#   'Twitter',
#   'intrusion'],
#  ['@',
#   'emilymariie',
#   'why',
#   'didnt',
#   'you',
#   'come',
#   'to',
#   'school',
#   '?',
#   '?',
#   'have',
#   'you',
#   'done',
#   'the',
#   'short',
#   'stack',
#   'thing',
#   'by',
#   'yourself',
#   ',',
#   'or',
#   'do',
#   'you',
#   'still',
#   'need',
#   'me',
#   '?'],
#  ['-',
#   '@',
#   'EvertB',
#   'which',
#   'one',
#   '?',
#   'http',
#   ':',
#   '//bit.ly/10o8LW',
#   ',',
#   'http',
#   ':',
#   '//bit.ly/Nh82S',
#   'or',
#   'http',
#   ':',
#   '//bit.ly/wr8Vz',
#   '-',
#   'latter',
#   'for',
#   'the',
#   'US',
#   'Store',
#   'only',
#   '#',
#   'iphone',
#   '#',
#   'comic'],
#  ['@',
#   'georgediaz',
#   '#',
#   'Magic',
#   '..',
#   'thinking',
#   'le',
#   'than',
#   '50',
#   '%',
#   'chance',
#   'Hedo',
#   'stay',
#   'in',
#   'Orlando',
#   '.',
#   'He',
#   "'s",
#   'gon',
#   'na',
#   'go',
#   'for',
#   'the',
#   '$',
#   '$',
#   '.',
#   'They',
#   'all',
#   'do',
#   '.',
#   'Ca',
#   "n't",
#   'blame',
#   'him',
#   'though',
#   '.'],
#  ['@',
#   'Glamicole',
#   '..',
#   'now',
#   'who',
#   'wud',
#   'make',
#   'this',
#   'beautiful',
#   'plc',
#   'cry',
#   '?'],
#  ['@',
#   'HaterMagazine',
#   ':',
#   '@',
#   'damienrandle',
#   'it',
#   'is',
#   'now',
#   'the',
#   'outer',
#   'fat',
#   'kid',
#   '.'],
#  ['-',
#   '@',
#   'haugern',
#   'The',
#   'server',
#   'are',
#   'now',
#   'backup',
#   ',',
#   'if',
#   'you',
#   'experience',
#   'any',
#   'more',
#   'problem',
#   'then',
#   'please',
#   'let',
#   'me',
#   'know',
#   'Sorry',
#   'about',
#   'the',
#   'delay',
#   '...'],
#  ['@',
#   'hawaiibuzz',
#   ':',
#   '&',
#   'quot',
#   ';',
#   'yes',
#   ',',
#   'i',
#   'am',
#   'lol',
#   'j/k',
#   'luv',
#   'this',
#   '!',
#   '@',
#   'DJDolceVita',
#   ':',
#   '&',
#   'quot',
#   ';',
#   'you',
#   'are',
#   'like',
#   'a',
#   'gentle',
#   'breeze',
#   'that',
#   'ha',
#   'blown',
#   'throug',
#   '...',
#   'â\x99',
#   '«',
#   'http',
#   ':',
#   '//blip.fm/~7s7mn'],
#  ['@',
#   'hellopnsdear',
#   'se',
#   'MORREA',
#   'a',
#   'mi',
#   'Joseph',
#   ',',
#   'no',
#   'no',
#   'se',
#   'vale',
#   '.'],
#  ['@',
#   'hidingesther',
#   '@',
#   'linininiooh',
#   'are',
#   'my',
#   'future',
#   'rooooooooomies',
#   '!',
#   'NYC',
#   'holleR'],
#  ['@',
#   'Hijack_King7',
#   'I',
#   'hope',
#   'u',
#   'have',
#   'cheeSe',
#   'burgerS',
#   '4',
#   '@',
#   'Snubbmatic',
#   'LMBO'],
#  ['@', 'iamyas', 'awesome'],
#  ['@',
#   'ivegotzooms',
#   'I',
#   'am',
#   'nothing',
#   'of',
#   'the',
#   'kind',
#   'and',
#   'everything',
#   'of',
#   'the',
#   'sort',
#   'http',
#   ':',
#   '//tr.im/mLsn'],
#  ['-',
#   '@',
#   'jerrybattiste',
#   '&',
#   'quot',
#   ';',
#   '..',
#   'pick',
#   'up',
#   'some',
#   'flower',
#   'for',
#   'the',
#   'teacher',
#   '..',
#   '&',
#   'quot',
#   ';',
#   'I',
#   "'m",
#   'jealous',
#   '!',
#   'I',
#   'want',
#   'flower',
#   'without',
#   'having',
#   'to',
#   'be',
#   'in',
#   'the',
#   'hospital',
#   'to',
#   'get',
#   'them',
#   '!'],
#  ['-',
#   '@',
#   'joaoqalves',
#   'Think',
#   'again',
#   'Talvez',
#   'seja',
#   'do',
#   'Ãªnfase',
#   'na',
#   'cifra',
#   '.',
#   'Mas',
#   'atenÃ§Ã£o',
#   ':',
#   '&',
#   'quot',
#   ';',
#   'Security',
#   'is',
#   'a',
#   'chain',
#   ';',
#   'it',
#   "'s",
#   'a',
#   'strong',
#   'a',
#   'the',
#   'weakest',
#   'link',
#   'â\x80¦'],
#  ['@',
#   'jonasbrothers',
#   'Why',
#   'is',
#   'your',
#   'YouTube',
#   'account',
#   'suspended',
#   '?',
#   'lol',
#   'Single',
#   'Ladies',
#   'dance',
#   '?',
#   'I',
#   'NEED',
#   'TO',
#   'WATCH',
#   'IT',
#   'AGAIN',
#   '!'],
#  ['-', '@', 'JuicyJones', 'I', 'know', '..', 'SOLD', 'OUT', 'though', '.'],
#  ['-',
#   '@',
#   'kaitymarine',
#   '-',
#   'watch',
#   'E3',
#   '@',
#   'MCMudkips',
#   '-',
#   'Will',
#   'do'],
#  ['-',
#   '@',
#   'katherineholden',
#   'Thanks',
#   'K',
#   '!',
#   'Here',
#   "'s",
#   'hoping',
#   '!',
#   'Pretty',
#   'nervous',
#   'though',
#   '...'],
#  ['@',
#   'katiedontcry',
#   'should',
#   'get',
#   'on',
#   'aim',
#   'and',
#   'talk',
#   'to',
#   'me',
#   '.',
#   'i',
#   'miss',
#   'her',
#   '.'],
#  ['@',
#   'kcome',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '1000',
#   'Followers',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   'http',
#   ':',
#   '//tr.im/mWKn'],
#  ['@',
#   'khead',
#   'I',
#   "'ll",
#   'tell',
#   'ya',
#   ',',
#   'grocery',
#   'store',
#   '.',
#   'It',
#   'wa',
#   'better',
#   'when',
#   'you',
#   'blasted',
#   'the',
#   'oldie',
#   '.',
#   'Sugar',
#   'Ray',
#   'doe',
#   'not',
#   'make',
#   'me',
#   '..',
#   'http',
#   ':',
#   '//tr.im/jd0y'],
#  ['@',
#   'kvetchingeditor',
#   "'s",
#   'kashrut',
#   'convo',
#   'make',
#   'me',
#   'want',
#   'to',
#   'keep',
#   'more',
#   'kosher',
#   'but',
#   'my',
#   'roomy',
#   'catholic',
#   '&',
#   'amp',
#   ';',
#   'he',
#   'ha',
#   'a',
#   'pork',
#   'loin',
#   'in',
#   'the',
#   'fridge',
#   '#',
#   'kosherFAIL'],
#  ['@',
#   'Leloz',
#   'is',
#   "n't",
#   'home',
#   'neither',
#   'is',
#   '@',
#   'sozi1',
#   '...',
#   '@',
#   'althani96',
#   'U',
#   'BETTER',
#   'HAVE',
#   'IT',
#   '!',
#   '!',
#   '!'],
#  ['@',
#   'LHSOPERAFIENDS',
#   'yall',
#   'bitch',
#   'better',
#   'wake',
#   'up',
#   'early',
#   'to',
#   'go',
#   'to',
#   'the',
#   'LA',
#   'Opera',
#   ',',
#   'kay',
#   '!',
#   '?'],
#  ['-',
#   '@',
#   'littlecharva',
#   '-',
#   'I',
#   "'m",
#   'immune',
#   'to',
#   'dentist',
#   "'",
#   'drill',
#   'etc',
#   'now',
#   ',',
#   'it',
#   'just',
#   'doe',
#   "n't",
#   'bother',
#   'me',
#   'at',
#   'all',
#   '.',
#   'Having',
#   'gum',
#   'lift',
#   'surgery',
#   'next',
#   'week',
#   'tho',
#   '*',
#   'eek',
#   '*'],
#  ['@',
#   'lolife4life',
#   'where',
#   'r',
#   'u',
#   'tonite',
#   'im',
#   'still',
#   'awake',
#   '!'],
#  ['@', 'lorinimus', 'hate', 'Bebot', 'App'],
#  ['@',
#   'masareus',
#   '&',
#   'quot',
#   ';',
#   '@',
#   'dhempe',
#   'congrats',
#   'bhai',
#   ',',
#   'but',
#   'like',
#   'the',
#   'oldie',
#   'in',
#   '&',
#   'gt',
#   ';',
#   'used',
#   'to',
#   'say',
#   '-',
#   'arre',
#   'bhai',
#   'kuch',
#   'kam',
#   'ka',
#   'http',
#   ':',
#   '//tr.im/ox5G'],
#  ['@', 'MelodyChase'],
#  ['@',
#   'mgph3nom',
#   'chilling',
#   'on',
#   'twitter',
#   'via',
#   'my',
#   'spanking',
#   'new',
#   'blackberry',
#   'w/',
#   'unlimited',
#   'internet',
#   ':',
#   'http',
#   ':',
#   '//tr.im/mZVC'],
#  ['@',
#   'michaelsarver',
#   'so',
#   'do',
#   'you',
#   'give',
#   'him',
#   'every',
#   'inch',
#   'of',
#   'your',
#   'love',
#   'every',
#   'night',
#   '?'],
#  ['@', 'mimbles', '@', 'WParenthetical'],
#  ["'",
#   '@',
#   'minghao',
#   'Maybe',
#   'you',
#   'can',
#   'pop',
#   '@',
#   'StarHubCares',
#   'a',
#   'tweet',
#   '.',
#   'They',
#   'are',
#   'quite',
#   'active',
#   'on',
#   'twitter',
#   '.'],
#  ['@',
#   'MsNovember',
#   'It',
#   "'s",
#   'a',
#   'shame',
#   'all',
#   'the',
#   'woman',
#   'in',
#   'Mamma',
#   'Mia',
#   'are',
#   'so',
#   'horny',
#   ',',
#   'since',
#   'all',
#   'the',
#   'men',
#   'on',
#   'this',
#   'island',
#   'are',
#   'so',
#   '..',
#   'http',
#   ':',
#   '//tr.im/kmET'],
#  ['-',
#   '@',
#   'nibaq',
#   'Thanks',
#   'for',
#   'letting',
#   'me',
#   'know',
#   '.',
#   'I',
#   "'m",
#   'going',
#   'to',
#   'check',
#   'out',
#   'Eureka',
#   'later',
#   'with',
#   'this',
#   'knowledge'],
#  ['@', 'Oneshine', 'What', 'are', 'u', 'referring', 'to', '?'],
#  ['@', 'plmusic22'],
#  ['-',
#   '@',
#   'PoisonGirl10',
#   'What',
#   "'s",
#   'up',
#   '?',
#   '@',
#   'sevgli',
#   'Hey',
#   'you',
#   '!',
#   '@',
#   'lowridergrl',
#   'I',
#   "'m",
#   'doing',
#   'ok',
#   ',',
#   'thx',
#   '.',
#   'You',
#   '?',
#   '@',
#   'cristinerafae',
#   'You',
#   ',',
#   'too',
#   '!',
#   'TTYL',
#   '!',
#   '@',
#   'Nic0pic0',
#   'Oh',
#   ',',
#   'sowwy',
#   '!',
#   'lol'],
#  ['@', 'RAPPUBLICIST', 'HAPPY', 'MOTHERS', 'DAY', '!'],
#  ['-',
#   '@',
#   'raybooysen',
#   'I',
#   'knew',
#   'Sharepoint',
#   'wa',
#   'written',
#   'by',
#   'intern',
#   ',',
#   'I',
#   'just',
#   'knew',
#   'it',
#   '!',
#   '!'],
#  ['I', 'miss', 'her', 'so', 'much', 'already', '...'],
#  ['just', 'practising', '.....', 'how', 'I', 'feel'],
#  ['Miss', 'my', 'love', 'Jamie'],
#  ['FUCK', 'YOU', '!'],
#  ['my', 'head', 'feel', 'like', 'a', 'bowling', 'ball'],
#  ['my', 'heart', 'hurt', 'badly', '...'],
#  ['FS',
#   'keep',
#   'crashing',
#   'when',
#   'I',
#   'try',
#   'to',
#   'load',
#   'Bungie',
#   'plane',
#   '.'],
#  ['My',
#   'current',
#   'headset',
#   'is',
#   'on',
#   'it',
#   'deathbed',
#   'now',
#   '!',
#   'My',
#   'dad',
#   'gave',
#   'it',
#   'to',
#   'me',
#   'just',
#   '3',
#   'week',
#   'back',
#   '!'],
#  ['....',
#   'My',
#   'mood',
#   'is',
#   'currently',
#   'BLAH',
#   '.',
#   'Sitting',
#   'in',
#   'a',
#   'parking',
#   'lot'],
#  ['I', 'am', 'happy'],
#  ['...', 'that', 'is', 'all', '.'],
#  ['everyone',
#   'went',
#   'home',
#   '.',
#   'and',
#   'not',
#   'everyone',
#   'wa',
#   'even',
#   'here',
#   '!',
#   '~CMF',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ['fed', 'up', '....'],
#  ['fuck', ',', 'fuck', ',', 'fuuuuck', '!'],
#  ['Not',
#   'feeling',
#   'it',
#   'today',
#   'And',
#   'to',
#   'make',
#   'matter',
#   'worst',
#   'it',
#   'super',
#   'nasty',
#   'and',
#   'rainy',
#   'outside',
#   ',',
#   'YUCK',
#   '!'],
#  ['@', 'Beansummer'],
#  ['Awwwwwh',
#   'i',
#   'wanted',
#   'Aiden',
#   'Davis',
#   '2',
#   'WIN',
#   ',',
#   'i',
#   '&',
#   'lt',
#   ';',
#   '3',
#   'him',
#   'so',
#   'bummed',
#   'he',
#   'didnt'],
#  ['bed', 'time', 'now', '....'],
#  ['Faltam', '4', 'dia', 'para', 'o', 'World', 'Drawing', 'day'],
#  ['Friends',
#   'like',
#   'these',
#   '...',
#   'no',
#   'thanks',
#   ',',
#   'I',
#   "'m",
#   'not',
#   'fake',
#   '!',
#   '^',
#   '^'],
#  ['haha',
#   'omg',
#   '.',
#   'stayin',
#   'steezy',
#   '&',
#   'amp',
#   ';',
#   'mowin',
#   'the',
#   'lawn',
#   '...',
#   'loviie',
#   'still',
#   'here',
#   '&',
#   'amp',
#   ';',
#   '&',
#   'amp',
#   ';',
#   'goiing',
#   'tanning',
#   'soon',
#   '.'],
#  ['i', 'think', 'my', 'bf', 'is', 'cheating', 'on', 'me', '!', '!', '!', '!'],
#  ['i',
#   'wan',
#   'na',
#   'play',
#   'with',
#   'my',
#   'camera',
#   'but',
#   'i',
#   'will',
#   'settle',
#   'for',
#   'playing',
#   'with',
#   'iv',
#   "'s",
#   'and',
#   'heart',
#   'monitor'],
#  ['i', 'want', 'an', 'octo', 'drive'],
#  ['I',
#   'want',
#   'to',
#   'display',
#   'my',
#   'pretty',
#   'voltron',
#   '!',
#   'Upside',
#   ',',
#   'I',
#   'get',
#   'two',
#   'pretty',
#   'voltrons',
#   '!'],
#  ['i',
#   'want',
#   'to',
#   'find',
#   'a',
#   'way',
#   'to',
#   'put',
#   'my',
#   'photo',
#   'on',
#   'phone',
#   'here',
#   'i',
#   'have',
#   'Bluetooth',
#   'in',
#   'both',
#   'phone',
#   'and',
#   'computer',
#   'but',
#   'it',
#   'doe',
#   "n't",
#   'work'],
#  ['IN',
#   'an',
#   'effort',
#   'to',
#   'bring',
#   'you',
#   'the',
#   'best',
#   'content',
#   'we',
#   'just',
#   'added',
#   'at',
#   'lease',
#   '30',
#   'hour',
#   'to',
#   'the',
#   'release',
#   'of',
#   'The',
#   'digital',
#   'Rapture',
#   '.',
#   'soon',
#   '...',
#   'hang',
#   'tight'],
#  ['--',
#   '-',
#   'is',
#   'our',
#   'response',
#   'to',
#   'what',
#   'happened',
#   'today',
#   '.',
#   'and',
#   'that',
#   'is',
#   'all',
#   '.'],
#  ['J', ',', 'you', 'are', 'right', '...', 'it', 'hurt', '.'],
#  ['kinda', 'but', 'not', 'really', ',', 'but', 'kinda'],
#  ['let',
#   "'s",
#   'have',
#   'a',
#   'moment',
#   'of',
#   'silence',
#   'for',
#   'our',
#   'childhood',
#   'home',
#   '...',
#   'sadly',
#   ',',
#   'it',
#   'ca',
#   "n't",
#   'be',
#   'replaced',
#   'and',
#   'we',
#   'can',
#   'never',
#   'go',
#   'back'],
#  ['lol', 'all', 'these', '#', 'robotpickuplines', 'are', 'hilarious'],
#  ['man',
#   ',',
#   'oh',
#   'man',
#   '(',
#   'i',
#   'should',
#   'punch',
#   'myself',
#   'in',
#   'the',
#   'head',
#   ',',
#   'but',
#   'im',
#   'ok',
#   'with',
#   'that',
#   ')'],
#  ['my',
#   'friend',
#   'can',
#   'get',
#   'with',
#   'ur',
#   'friend',
#   'and',
#   'we',
#   'can',
#   'all',
#   'b',
#   'friend',
#   ',',
#   'shit',
#   ',',
#   'we',
#   'could',
#   'do',
#   'this',
#   'every',
#   'weeknd',
#   '..',
#   'Aiigght',
#   '?',
#   'with',
#   'coop',
#   'n',
#   'the',
#   'crew'],
#  ['No',
#   'man',
#   'is',
#   'worth',
#   'your',
#   'tear',
#   ',',
#   'and',
#   'the',
#   'one',
#   'that',
#   'is',
#   'wo',
#   "n't",
#   'make',
#   'you',
#   'cry',
#   '!'],
#  ['rain', 'rain', 'go', 'away', '!'],
#  ['storm', 'are', 'scary', '!'],
#  ['such',
#   'a',
#   'beautiful',
#   'satisfying',
#   'day',
#   'of',
#   'bargain',
#   'shopping',
#   '.',
#   'love',
#   'it',
#   '.'],
#  ['Tell', 'those', 'girl', 'your', 'clocking', 'out', 'lol'],
#  ['thank',
#   'god',
#   'today',
#   'is',
#   'friday',
#   '!',
#   '!',
#   '!',
#   'I',
#   'love',
#   'Ti',
#   'Ti',
#   '!',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ['the',
#   'batt',
#   'to',
#   'my',
#   'internet',
#   'connection',
#   'died',
#   '.',
#   'Guess',
#   'it',
#   'back',
#   'to',
#   'the',
#   'mobile',
#   '!'],
#  ['thrilled', 'about', 'being', 'at', 'work', 'this', 'morning'],
#  ['we',
#   'break',
#   'dance',
#   'not',
#   'heart',
#   'by',
#   'Short',
#   'Stack',
#   'is',
#   'my',
#   'ringtone',
#   '....',
#   'i',
#   'LOVE',
#   'that',
#   'song',
#   '!',
#   '!',
#   '!',
#   '.....'],
#  ['www.apple.com/iphone', 'now', 'ha', 'it', 'for', 'the', '18th'],
#  ['#',
#   'squarespace',
#   '#',
#   'trackle',
#   'no',
#   'apple',
#   'iphone',
#   'card',
#   'for',
#   'u',
#   'maybe',
#   'tomorrow',
#   '!',
#   'I',
#   'guess',
#   'it',
#   'help',
#   'if',
#   'you',
#   'tweet',
#   'it',
#   'huh',
#   '?',
#   'We',
#   'forgot'],
#  ['(',
#   'unsure',
#   ')',
#   '(',
#   'hassle',
#   ')',
#   '(',
#   ':',
#   '(',
#   'music',
#   ')',
#   'http',
#   ':',
#   '//plurk.com/p/yq08l'],
#  ['exhausted'],
#  ['i',
#   'want',
#   'some',
#   'ben',
#   '&',
#   'amp',
#   ';',
#   'jerry',
#   'cake',
#   'batter',
#   'please',
#   'ugh'],
#  ['my',
#   'life',
#   'is',
#   'very',
#   'lazzzzyyyy',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*'],
#  ['wish', 'ella', 'wa', 'on', 'or', 'somebody', ',', ',', ',', ','],
#  ['ish', 'in', 'a', 'good', 'mood', '.....', 'tlk', 'to', 'me'],
#  ['i',
#   'think',
#   'i',
#   "'m",
#   'going',
#   'to',
#   'go',
#   '3',
#   'a',
#   'long',
#   'drive',
#   'then',
#   'when',
#   'i',
#   'get',
#   'to',
#   'the',
#   'pacific',
#   'ocean',
#   'open',
#   'my',
#   'car',
#   'door',
#   'and',
#   'throw',
#   'my',
#   'pc',
#   'in',
#   'the',
#   'ocean'],
#  ['what', 'the', 'hell', 'BBC', '?'],
#  ['#', 'canuck'],
#  ['I', 'dont', 'like', 'this', 'weekend', '..', 'Huhuhu', '(', '('],
#  ['I', "'ll", 'get', 'on', 'it', 'right', 'away', '!'],
#  ['-',
#   'J',
#   '+',
#   'A',
#   'MADE',
#   'NiCE',
#   '.....',
#   'TWiCE',
#   '!',
#   'for',
#   'now',
#   ';',
#   ']'],
#  ['love', 'life', 'atm', '!', 'it', 'brilliant', 'XD'],
#  ['who', 'else', 'is', 'in', 'a', 'happy', 'mood', '?', '?', '=D'],
#  ['!', 'BYE', 'EVERYONE', '!'],
#  ['...', 'lonely', 'night'],
#  ['blue', 'doe', 'not', 'work'],
#  ['geez', 'I', "'m", 'feeling', 'their', 'pain'],
#  ['i', 'miss', 'my', 'summertime', 'daley', '.'],
#  ['on',
#   'the',
#   'computer',
#   '...',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '*',
#   'ill',
#   '*',
#   'lol',
#   ',',
#   'no',
#   'fuckin',
#   'goin',
#   'to',
#   'portugal'],
#  ['SO', 'FAR', 'SO', 'GOOD', '!'],
#  ['TODAY', 'WAS', 'A', 'GREAT', 'DAY', '!', '!', '!'],
#  ['UGHHHHHHHHHHHHHHHHHHHHHHHHHHHHH'],
#  ['#', 'Battleground'],
#  ['a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   ',',
#   'a',
#   'lot',
#   '.'],
#  ['Awwwwwh',
#   'i',
#   'wanted',
#   'Aiden',
#   'Davis',
#   '2',
#   'WIN',
#   'i',
#   '&',
#   'lt',
#   ';',
#   '3',
#   'him',
#   'so',
#   'bummed',
#   'he',
#   'didnt'],
#  ['Curtain',
#   'drop',
#   'at',
#   'the',
#   'Crown',
#   'Uptown',
#   'after',
#   '32',
#   'ye',
#   'http',
#   ':',
#   '//www.kansas.com/news/featured/story/860875.html'],
#  ['eh', 'must', 'leave', 'New', 'Mexico', 'and', 'soon', '!'],
#  ['fail', 'math', 'i', 'knew', 'it', 'i', 'wa', 'just', 'too', 'slow'],
#  ['From',
#   'Gongwer',
#   'OH',
#   'Report',
#   ',',
#   'sound',
#   'like',
#   'leadership',
#   'still',
#   'considering',
#   'library',
#   'cut',
#   ',',
#   'not',
#   'considering',
#   'tax',
#   'increase',
#   '.',
#   '#',
#   'saveohiolibraries'],
#  ['fuck',
#   'sake',
#   '.',
#   'Why',
#   'can',
#   'thing',
#   'never',
#   'work',
#   'out',
#   'for',
#   'me',
#   '?'],
#  ['-',
#   'going',
#   'in',
#   'town',
#   'todaÑ\x87',
#   'with',
#   'mÑ\x87',
#   'cousinnn',
#   ',',
#   '[',
#   'Ñ\x87',
#   ']',
#   'netball',
#   'match',
#   'wa',
#   'cancelledd'],
#  ['hoping', 'to', 'see', 'my', 'baby', 'girl'],
#  ['i', 'do', "n't", 'even', 'know', '.'],
#  ['I', 'just', 'lost', 'a', 'member', 'of', 'my', 'family'],
#  ['I', "'m", 'SICK', 'of', 'bedtime', 'battle'],
#  ['i',
#   "'m",
#   'so',
#   'cold',
#   'this',
#   'morning',
#   '......',
#   'i',
#   'have',
#   'chill',
#   'all',
#   'over',
#   '.....'],
#  ['Just', '...'],
#  ['No',
#   'no',
#   'no',
#   '.',
#   'Tonight',
#   'go',
#   'on',
#   'the',
#   'book',
#   'a',
#   'the',
#   'worst',
#   'SYTYCD',
#   'result',
#   'show',
#   '.'],
#  ['no', 'shopping'],
#  ['-',
#   'Poor',
#   'lil',
#   'mousey',
#   ',',
#   'just',
#   'out',
#   'enjoying',
#   'the',
#   'sunny',
#   'day',
#   '.',
#   'I',
#   'do',
#   "n't",
#   'think',
#   'I',
#   "'d",
#   'feel',
#   'so',
#   'bad',
#   'if',
#   'it',
#   'wa',
#   'a',
#   'big',
#   'gnarly',
#   'rat',
#   'though',
#   '.',
#   'Dbl',
#   'standard',
#   '?',
#   'Yep',
#   '.'],
#  ['--', 'that', "'s", 'an', 'EPIC', 'sad', 'face', '.'],
#  ['This',
#   'magazine',
#   'story',
#   'just',
#   'broke',
#   'my',
#   'heart',
#   'at',
#   'the',
#   'dentist',
#   "'s",
#   'office',
#   'today',
#   ':',
#   'http',
#   ':',
#   '//tinyurl.com/ngbq2c'],
#  ['Tiger',
#   'Woods',
#   'is',
#   'up',
#   'by',
#   '2at',
#   '18',
#   'via',
#   'http',
#   ':',
#   '//nascar.com/racebuddy'],
#  ['wan',
#   'na',
#   'go',
#   'meet',
#   'wifey',
#   'but',
#   'ca',
#   "n't",
#   '....',
#   'this',
#   'sux',
#   ':',
#   "'",
#   '('],
#  ['Wondering',
#   'why',
#   'I',
#   'feel',
#   'like',
#   'I',
#   'do',
#   '...',
#   'I',
#   "'ll",
#   'feel',
#   'better',
#   'though',
#   '...',
#   'Its',
#   'all',
#   'good',
#   '!',
#   'I',
#   "'ll",
#   'be',
#   'happy',
#   'inspite',
#   'of',
#   '...',
#   'Tweet',
#   'ya',
#   'lata'],
#  ['yippeeeee',
#   'yay',
#   'let',
#   'gather',
#   'in',
#   'the',
#   'hay',
#   '...',
#   'HIS',
#   'LOVE',
#   'FOUND',
#   'IT',
#   "'S",
#   'WAY+',
#   'boy',
#   ',',
#   'it',
#   "'s",
#   'Gon',
#   'na',
#   'STAY',
#   'added',
#   '2',
#   'the',
#   'Master',
#   "'s",
#   'HOLY',
#   'WAY',
#   ':',
#   'ALL',
#   'HIS',
#   'WILL+WAY'],
#  ['#',
#   'IranElection',
#   '-',
#   'no',
#   'one',
#   'realizes',
#   'how',
#   'deep',
#   'this',
#   'go',
#   '.'],
#  ['&',
#   'gt',
#   ';',
#   '.',
#   'Bodies',
#   'from',
#   'Air',
#   'France',
#   'crash',
#   'have',
#   'been',
#   'found',
#   'http',
#   ':',
#   '//twurl.nl/dvu8be',
#   '(',
#   'via',
#   '@',
#   'Paisano',
#   ')'],
#  ['&',
#   'lt',
#   ';',
#   'that',
#   'is',
#   'the',
#   'story',
#   'of',
#   'my',
#   'life',
#   ',',
#   'a',
#   'whole',
#   'bunch',
#   'of',
#   'frownies',
#   '!'],
#  ['I',
#   'HAVE',
#   'NOOOOOOOOOO',
#   'FRIENDS',
#   'ON',
#   'TWITTER',
#   'IT',
#   'MAKES',
#   'ME',
#   'SAD',
#   'WILL',
#   'SOMEONE',
#   'FOLLOW',
#   'ME'],
#  ['i',
#   'just',
#   'want',
#   'to',
#   'hear',
#   'from',
#   'you',
#   '.',
#   'i',
#   'guess',
#   'that',
#   "'s",
#   'asking',
#   'too',
#   'much',
#   '..'],
#  ['Hardest',
#   'working',
#   'chica',
#   'i',
#   'know',
#   '(',
#   'mii',
#   'bos',
#   'lady',
#   ')',
#   '@',
#   'MoneyAceweather',
#   '(',
#   'look',
#   'up',
#   'to',
#   'her',
#   'seriously',
#   ')',
#   'lOl'],
#  ['i', 'really2', 'do', "n't", 'like', 'this', 'condition', '.', 'suck'],
#  ['Orlando',
#   'Lost',
#   'The',
#   'Series',
# ...
#   'is',
#   'happy'],
#  ['-',
#   '@',
#   'libraritarian59',
#   'Oh',
#   'no',
#   '!',
#   '@',
#   'donutspy',
#   'is',
#   "n't",
#   'a',
#   'good',
#   'link',
#   '!'],
#  ['-',
#   '@',
#   'littlecharva',
#   '-',
#   'if',
#   'the',
#   'front',
#   'wa',
#   "n't",
#   'black',
#   'on',
#   'both',
#   ',',
#   'I',
#   'would',
#   'have',
#   'got',
#   'the',
#   'white',
#   'one',
#   '.',
#   'As',
#   'it',
#   'is',
#   ',',
#   'the',
#   'black',
#   'look',
#   'sleek',
#   '&',
#   'amp',
#   ';',
#   'the',
#   'white',
#   'doe',
#   "n't"],
#  ['-',
#   '@',
#   'littlecharva',
#   '-',
#   'the',
#   'full',
#   'voice',
#   'control',
#   'is',
#   'making',
#   'me',
#   'want',
#   'iPhone',
#   '3GS',
#   ',',
#   'but',
#   '02',
#   'will',
#   'charge',
#   'me',
#   'a',
#   'fortune',
#   'a',
#   'my',
#   '3G',
#   'contract',
#   'not',
#   'up',
#   'til',
#   'April'],
#  ['@',
#   'MaMii_THiCKNESS',
#   'do',
#   "n't",
#   'do',
#   'dat',
#   '.',
#   'jst',
#   'tell',
#   'em',
#   '2',
#   'suck',
#   'ur',
#   'dyck',
#   '!',
#   'that',
#   'always',
#   'make',
#   'me',
#   'feel',
#   'better'],
#  ['-',
#   '@',
#   'MelbourneVixens',
#   'Awesome',
#   '4th',
#   'quarter',
#   'lady',
#   '!',
#   'Great',
#   'game'],
#  ['@', 'monique4ever', 'is', 'messing', 'with', 'my', 'mind', '.'],
#  ['@', 'netfart', 'quite', 'the', 'opposite'],
#  ['-',
#   '@',
#   'nikkofelipe',
#   'night',
#   ',',
#   'and',
#   'thanks',
#   'for',
#   'the',
#   'call'],
#  ['@', 'ohhushaubrey', 'it', 'make', 'me', 'wan', 'na', 'cry'],
#  ['@',
#   'PAN1F',
#   '@',
#   'OregonMJW',
#   'No',
#   ',',
#   'I',
#   'do',
#   'know',
#   'the',
#   'difference',
#   '!',
#   'Like',
#   'I',
#   'say',
#   ',',
#   'it',
#   "'s",
#   'been',
#   'a',
#   'long',
#   'time',
#   '.',
#   'A',
#   'very',
#   'long',
#   'time',
#   'http',
#   ':',
#   '//tr.im/nJOo'],
#  ['@',
#   'PhillMason',
#   '@',
#   'Philoscribe',
#   'Thank',
#   'you',
#   '.',
#   'I',
#   'am',
#   'genuinely',
#   'grateful'],
#  ['-',
#   '@',
#   'PinkElephant73',
#   'So',
#   'pretty',
#   'much',
#   'you',
#   'look',
#   'like',
#   'a',
#   'candy',
#   'floss',
#   'machine',
#   'today'],
#  ['@',
#   'prblog',
#   '@',
#   'steverubel',
#   'posterous',
#   'look',
#   'like',
#   'tumblr',
#   'for',
#   'iPhone',
#   '?',
#   'look',
#   'interesting',
#   '.',
#   'can',
#   'you',
#   'fold',
#   'this',
#   'content',
#   '..',
#   'http',
#   ':',
#   '//tr.im/nhcv'],
#  ['Dont', 'Wan', 'na', 'Leave', 'NY', 'Today', '.'],
#  ["'",
#   'dont',
#   'worry',
#   'about',
#   'the',
#   'for',
#   'amigo',
#   '!',
#   '!',
#   'there',
#   'still',
#   'hangin',
#   'in',
#   'there',
#   "'",
#   '&',
#   'lt',
#   ';',
#   '//3'],
#  ['down', 'to', '3k', 'in', 'chip', '.'],
#  ['downloaded',
#   'one',
#   'movie',
#   'yesterday',
#   'and',
#   'having',
#   'some',
#   'problem',
#   'with',
#   'that',
#   ',',
#   'i',
#   'thnk',
#   'i',
#   'deserve',
#   'that',
#   '...'],
#  ['Driving',
#   'Lizzie',
#   'to',
#   'the',
#   'airport',
#   '.',
#   'Say',
#   'good',
#   'bye',
#   'Lizzie',
#   '.'],
#  ['--',
#   'DT',
#   'tonight',
#   ';',
#   'DT',
#   'tomorrow',
#   'day',
#   '&',
#   'amp',
#   ';',
#   'night',
#   'beauty',
#   '.'],
#  ['dude',
#   'I',
#   'almost',
#   'just',
#   'shocked',
#   'myself',
#   '.',
#   'Lesson',
#   'learned',
#   'never',
#   'get',
#   'outta',
#   'the',
#   'shower',
#   'and',
#   'think',
#   'electricity',
#   'wo',
#   "n't",
#   'hate',
#   'on',
#   'ur',
#   'as',
#   '.'],
#  ['-',
#   'eaten',
#   'some',
#   'steak',
#   '!',
#   '!',
#   '!',
#   'im',
#   'feeling',
#   'good',
#   '!',
#   'much',
#   'better',
#   '!',
#   '!',
#   'missing',
#   'my',
#   'lady',
#   'though'],
#  ['eating', 'my', 'last', 'wizz', 'fizz'],
#  ['ECL',
#   'all',
#   'day',
#   'to',
#   'try',
#   'to',
#   'cram',
#   'all',
#   'of',
#   'this',
#   'organic',
#   'chemistry',
#   'back',
#   'into',
#   'my',
#   'head',
#   '.',
#   'Final',
#   'tomorrow',
#   '.',
#   'ugh'],
#  ['eff', 'that', 'bitch', 'at', 'Dunkin', 'Donuts'],
#  ['elise', 'and', 'melanie', 'are', 'the', 'SHIZ', ','],
#  ['ellie',
#   'just',
#   'text',
#   'me',
#   'saying',
#   '&',
#   'quot',
#   ';',
#   'theyre',
#   'not',
#   'gona',
#   'read',
#   'our',
#   'text',
#   'are',
#   'they',
#   '?',
#   '&',
#   'quot',
#   ';',
#   'I',
#   'WILL',
#   'SPEAK',
#   'TO',
#   'MCFLY',
#   '!'],
#  ['emotional', '.'],
#  ['Everton',
#   'F.C',
#   '.',
#   'just',
#   'got',
#   'beat',
#   'in',
#   'the',
#   'Finals',
#   'of',
#   'the',
#   'F.A',
#   '.',
#   'Cup',
#   'against',
#   'Chealea',
#   'F.C',
#   '.',
#   'Oh',
#   'well',
#   ',',
#   'at',
#   'least',
#   'we',
#   'got',
#   'to',
#   'the',
#   'final',
#   'and',
#   'played',
#   'well',
#   '!'],
#  ['everton', '.', 'oh', 'well', '.', 'lol', '.'],
#  ['every', 'fucking', 'day'],
#  ['every',
#   'one',
#   'i',
#   'wa',
#   'talking',
#   'to',
#   'on',
#   'msn',
#   'ha',
#   'gone',
#   'offline',
#   'and',
#   'i',
#   'wo',
#   "n't",
#   'be',
#   'able',
#   'to',
#   'talk',
#   'till',
#   'them',
#   'tomorrow',
#   'i',
#   'feel',
#   'lonely',
#   ':',
#   "'",
#   '(',
#   'x'],
#  ['-',
#   'Every',
#   'so',
#   'often',
#   'I',
#   'catch',
#   'my',
#   'own',
#   'reflection',
#   '&',
#   'amp',
#   ';',
#   'think',
#   '..',
#   'Now',
#   'that',
#   "'s",
#   'one',
#   'cool',
#   'son-of-a-b',
#   '*',
#   'tch',
#   '..',
#   'today',
#   "'s",
#   'one',
#   'of',
#   'those',
#   'day'],
#  ['every',
#   'time',
#   'i',
#   'leave',
#   'my',
#   'room',
#   ',',
#   'i',
#   'miss',
#   'bubu',
#   'sending',
#   'me',
#   'a',
#   'msg',
#   'and',
#   'then',
#   'he',
#   "'s",
#   'gone',
#   ',',
#   'same',
#   'on',
#   'my',
#   'side.its',
#   'been',
#   'hapnin',
#   'all',
#   'day',
#   '...',
#   'universe',
#   '?',
#   '!',
#   '!',
#   'mxit',
#   'then'],
#  ['everyones', 'drunk', 'but', 'me'],
#  ['everyones', 'dying', 'or', 'bordeirlne', 'on', 'SVU'],
#  ['Exams', '.....', 'help', '!'],
#  ['expensive', 'car', 'repair'],
#  ['Explore', 'twitter'],
#  ['F', '%', '$', '&', 'amp', ';', 'ing', 'Red', 'Wings', '!'],
#  ['failed',
#   'inspection',
#   '.',
#   'Did',
#   'you',
#   'know',
#   'you',
#   'can',
#   'pas',
#   'wo/oven',
#   ',',
#   'but',
#   'not',
#   'wo/anti-tip',
#   'bracket',
#   ',',
#   'which',
#   'is',
#   'only',
#   'sold',
#   'w/oven',
#   '?',
#   'This',
#   'is',
#   'worse',
#   'than',
#   'tax',
#   '.'],
#  ['failing',
#   'at',
#   'everything',
#   'i',
#   'should',
#   'just',
#   'give',
#   'up',
#   'now',
#   '....'],
#  ['Famed',
#   'Michigan',
#   'bookstore',
#   'to',
#   'close',
#   'it',
#   'door',
#   'http',
#   ':',
#   '//u.mavrev.com/bc7v'],
#  ['famliy',
#   'going',
#   'bck',
#   'homee',
#   'and',
#   'have',
#   'too',
#   'taKE',
#   'sister',
#   'hores',
#   'riding',
#   'oh',
#   'no',
#   'gon',
#   'na',
#   'be',
#   'a',
#   'boring',
#   'day'],
#  ['Farrah',
#   'Fawcett',
#   'dy',
#   'of',
#   'cancer',
#   'at',
#   '62.',
#   'http',
#   ':',
#   '//bit.ly/OnhYd'],
#  ['fcukk', 'you', '!'],
#  ['fedex',
#   'will',
#   'be',
#   'kicked',
#   'out',
#   'of',
#   'the',
#   'french',
#   'open',
#   '...'],
#  ['feelin', 'very', 'pessimistic', ')', ':'],
#  ['feeling', 'a', 'litle', 'sad'],
#  ['feeling', 'all', 'sad', 'leaving', 'mumbai', '...'],
#  ['feeling',
#   'down',
#   '.',
#   'reality',
#   'is',
#   'setting',
#   'in',
#   '.',
#   'i',
#   'know',
#   'i',
#   'should',
#   'be',
#   'beyond',
#   'this',
#   'point',
#   '.',
#   'why',
#   'am',
#   'i',
#   'still',
#   'here',
#   '?',
#   'i',
#   'want',
#   'to',
#   'follow',
#   'my',
#   'dream',
#   'but',
#   'im',
#   'scared'],
#  ['Feels', 'bad', 'for', 'Cali', '...', 'poor', 'thing', '.'],
#  ['female',
#   'model',
#   'tortured',
#   'by',
#   'prince',
#   'http',
#   ':',
#   '//tinyurl.com/mbmanohara'],
#  ['ferret', 'are', 'much', 'cooler', 'than', 'fish', '.'],
#  ['FIELD', 'TRIP', 'TODAY', 'LEAVING', 'NOW', ':3'],
#  ['-',
#   'finally',
#   'at',
#   'home',
#   ';',
#   'bout',
#   'to',
#   'napp',
#   ',',
#   'then',
#   'get',
#   'ready',
#   'for',
#   'college',
#   'tomorrow',
#   'ughhh',
#   ';',
#   'sooo',
#   'excited',
#   '!'],
#  ['Finally',
#   'managed',
#   'to',
#   'check',
#   'the',
#   'Euromillions',
#   'result',
#   '......',
#   'NO',
#   'ï¿½89',
#   'million',
#   'for',
#   'me',
#   'I',
#   "'m",
#   'afraid',
#   ':',
#   '[',
#   'Oh',
#   'well',
#   '...',
#   'you',
#   'got',
#   'ta',
#   'be',
#   'in',
#   'it',
#   'to',
#   'win',
#   'it',
#   '!'],
#  ['finding',
#   'out',
#   'the',
#   'Hollywood',
#   'Video',
#   'i',
#   'frequent',
#   ',',
#   'is',
#   'not',
#   're-model-ing',
#   ',',
#   'and',
#   'is',
#   'in',
#   'fact',
#   ',',
#   'closed',
#   '*',
#   'cancel',
#   'account',
#   '*',
#   'so',
#   'much',
#   '4',
#   'super',
#   'cheap',
#   'DVDs'],
#  ['@',
#   'PurpleHazeYobi',
#   'Hope',
#   'you',
#   'had',
#   'fun',
#   'with',
#   '&',
#   'quot',
#   ';',
#   'Lisa',
#   '&',
#   'quot',
#   ';',
#   'the',
#   'Jillian',
#   'replacement',
#   'lol',
#   '...',
#   'I',
#   'wa',
#   'busy',
#   'getting',
#   '@',
#   '_rosiecakes',
#   'drunk',
#   '!',
#   'lol',
#   'I',
#   '&',
#   'lt',
#   ';',
#   '3',
#   'u',
#   'both',
#   '...',
#   'xo'],
#  ['@',
#   'richietachie',
#   'i',
#   'missed',
#   'all',
#   '..',
#   'imma',
#   'call',
#   'u',
#   'tomorrow',
#   '..',
#   'and',
#   'reduce',
#   'the',
#   'number',
#   'of',
#   'Qs',
#   'by',
#   'tomorrow',
#   'pls',
#   '...',
#   'i',
#   'have',
#   'a',
#   'phobia',
#   'for',
#   'that',
#   'lol',
#   'seriously'],
#  ['@',
#   'rickswift',
#   '#',
#   'followfriday',
#   'these',
#   'ppl',
#   'or',
#   'catch',
#   'crab',
#   '@',
#   'KarlKleese',
#   '@',
#   'lpjdesign',
#   '@',
#   'LostZombies',
#   '@',
#   'pinkraygun',
#   '@',
#   'BittenbyBooks',
#   '@',
#   'hippojuicefilm',
#   '@',
#   'zazzle'],
#  ['@',
#   'SandyU',
#   '@',
#   'MightyBoognish',
#   '@',
#   'kittyireland',
#   'It',
#   "'s",
#   'light',
#   'with',
#   'a',
#   'bit',
#   'of',
#   'punch',
#   '.',
#   'Mission=San',
#   'Francisco',
#   'gin',
#   ',',
#   'Mexican',
#   'liqueur',
#   ',',
#   'seemed',
#   'an',
#   'apt',
#   'name',
#   '.'],
#  ['@',
#   'Savage_Death55',
#   'I',
#   'am',
#   'super',
#   'emo',
#   'about',
#   'stupid',
#   'stuff',
#   'rn',
#   ',',
#   'and',
#   'SG',
#   'is',
#   'making',
#   'me',
#   'feel',
#   'better',
#   '.',
#   ':',
#   'p'],
#  ['@', 'sf_giants', 'bullpen', 'loses', 'lead'],
#  ['@',
#   'ShawnaShameless',
#   '&',
#   'amp',
#   ';',
#   '@',
#   'killavilla',
#   'if',
#   'anyone',
#   'else',
#   'said',
#   'something',
#   'it',
#   "'s",
#   'to',
#   'you',
#   'too',
#   '.'],
#  ['@',
#   'Spiral_galaxy',
#   '@',
#   'YMPtweet',
#   'i',
#   'mean',
#   'we',
#   'have',
#   'the',
#   'best',
#   'religion',
#   'the',
#   'only',
#   'thing',
#   'that',
#   'we',
#   'have',
#   'to',
#   'do',
#   'is',
#   'to',
#   'follow',
#   'it',
#   'the',
#   'right',
#   'way'],
#  ['@',
#   'StephenHDunn',
#   'bow',
#   'out',
#   'of',
#   'the',
#   'Raid',
#   '.',
#   '&',
#   'quot',
#   ';',
#   'Dunn',
#   '&',
#   'quot',
#   ';',
#   'his',
#   'back',
#   'Inn',
#   '.',
#   'Speedy',
#   'recovery',
#   'mate',
#   '.'],
#  ['@', 'stevijean', 'yeahuhh'],
#  ['@',
#   'sylvanus',
#   'is',
#   'having',
#   'the',
#   'worse',
#   'day',
#   'ever',
#   '.',
#   'Boss',
#   'is',
#   'spazzing',
#   'out',
#   'at',
#   'work',
#   'and',
#   'finally',
#   'done',
#   'with',
#   'a',
#   'late',
#   'night',
#   'photo',
#   'shoot',
#   ',',
#   'only',
#   'to',
#   'have',
#   'a',
#   'flat'],
#  ['@',
#   'tahninial',
#   'just',
#   'called',
#   'me',
#   'a',
#   'cheeseburglar',
#   '.',
#   'He',
#   'made',
#   'me',
#   'sad'],
#  ['@',
#   'taylorswift13',
#   'didnt',
#   'win',
#   'the',
#   'first',
#   'award',
#   'she',
#   'wa',
#   'nominated',
#   'for',
#   '.',
#   'Oh',
#   'well',
#   '..',
#   'Shes',
#   'tied',
#   'for',
#   'most',
#   'nomination',
#   '.'],
#  ['@',
#   'Tellman',
#   'say',
#   ',',
#   '&',
#   'quot',
#   ';',
#   'Crush',
#   'the',
#   'Commies',
#   '&',
#   'quot',
#   ';',
#   '=',
#   'sad',
#   '.',
#   'My',
#   'grandfather',
#   ',',
#   'RIP',
#   ',',
#   'wa',
#   'a',
#   'Commie',
#   '@',
#   'Tellman'],
#  ['-',
#   '@',
#   'TendaiJoe',
#   'well',
#   'none',
#   'of',
#   'u',
#   'are',
#   'getting',
#   'out',
#   'of',
#   'here',
#   'alive',
#   'but',
#   'we',
#   'would',
#   'like',
#   'to',
#   'stay',
#   'a',
#   'while.I',
#   'wish',
#   'people',
#   'would',
#   'stop',
#   'killing',
#   'each',
#   'other'],
#  ['@',
#   'the_prodigy',
#   'AND',
#   '@',
#   'NKOTB',
#   'in',
#   'Boston',
#   '2day',
#   'Boo',
#   '!',
#   '!',
#   'Roll',
#   'on',
#   'summer',
#   'already',
#   '!',
#   '!',
#   '!',
#   'x'],
#  ['@',
#   'therealglambert',
#   'sorry',
#   '...',
#   'got',
#   'carried',
#   'away',
#   'with',
#   'gossip',
#   'on',
#   'another',
#   'note',
#   ':',
#   'Pass',
#   'on',
#   'a',
#   'Hippo',
#   'Birdie',
#   '&',
#   'amp',
#   ';',
#   'a',
#   'big',
#   'koala',
#   'hug',
#   'to',
#   'KRIS',
#   'for',
#   'me',
#   '!',
#   'xoxo',
#   'K'],
#  ['@',
#   'thesmartmama',
#   'I',
#   'have',
#   'no',
#   'office',
#   '.',
#   'I',
#   'know',
#   'this',
#   'is',
#   'hard',
#   'to',
#   'believe',
#   ',',
#   'but',
#   'people',
#   'do',
#   "n't",
#   'want',
#   'to',
#   'employ',
#   'me',
#   '.'],
#  ['@', 'ThisChicsFlava', ':', '@', 'DaPrbmChild', 'lmao', '&', 'lt', ';', '3'],
#  ['@',
#   'tommcfly',
#   'hi',
#   'when',
#   'ur',
#   'back',
#   '&',
#   'amp',
#   ';',
#   'when',
#   'ur',
#   'next',
#   'in',
#   'mk',
#   'i',
#   'am',
#   'gona',
#   'need',
#   '1',
#   'of',
#   'your',
#   'really',
#   'good',
#   'hug',
#   'that',
#   'only',
#   'you',
#   'and',
#   'my',
#   'friend',
#   'liam',
#   'can',
#   'give',
#   'ok',
#   '.'],
#  ['@',
#   'tweetdeck',
#   'lost',
#   'my',
#   'group',
#   ',',
#   'and',
#   'thats',
#   'not',
#   'a',
#   'good',
#   'thing',
#   'with',
#   '23k',
#   'follower'],
#  ['@',
#   'WeeLaura',
#   'Guardian',
#   'UK',
#   ':',
#   '12',
#   'student',
#   'reported',
#   'killed',
#   'in',
#   'crackdown',
#   'after',
#   'violent',
#   'clash',
#   'in',
#   '#',
#   'Iran',
#   'http',
#   ':',
#   '//bit.ly/wHLBv'],
#  ['@',
#   'YMPtweet',
#   '@',
#   'Spiral_galaxy',
#   'but',
#   'so',
#   'badly',
#   'no',
#   'one',
#   'doe',
#   ',',
#   'i',
#   'know',
#   'that',
#   'there',
#   'is',
#   'more',
#   'but',
#   'that',
#   "'s",
#   'what',
#   'i',
#   'got',
#   'so',
#   'far'],
#  ['@',
#   'zeldman',
#   'just',
#   'said',
#   'on',
#   'Flickr',
#   're',
#   'a',
#   'Mac',
#   'that',
#   'would',
#   "n't",
#   'install',
#   'OS',
#   'X',
#   '(',
#   'yes',
#   ')',
#   ':',
#   '&',
#   'quot',
#   ';',
#   'As',
#   'user-focused',
#   'design',
#   'go',
#   ',',
#   'this',
#   'is',
#   'an',
#   'exploding',
#   'colostomy',
#   'bag',
#   '&',
#   'quot',
#   ';'],
#  ['__cheer', 'up', 'emo', 'kid', '.'],
#  ['~', 'LVATT', 'IS', 'COMMING', '!', '!', '!', '~'],
#  ['=', 'next', 'few', 'day'],
#  ['=', ']', 'happy', 'sunday', '=', ']'],
#  ['1',
#   'dinger',
#   'in',
#   'and',
#   'I',
#   'so',
#   'regret',
#   'popping',
#   'that',
#   'pill',
#   '...'],
#  ['1',
#   'month',
#   'of',
#   'bed',
#   'by',
#   '1:30AM',
#   ',',
#   'already',
#   'failing',
#   'a',
#   'you',
#   'can',
#   'see'],
#  ['2',
#   'day',
#   'I',
#   'have',
#   "n't",
#   'tlkd',
#   '2',
#   'mi',
#   'amor',
#   '..',
#   'im',
#   'kinda',
#   'stubborn',
#   'when',
#   'it',
#   'come',
#   '2',
#   'my',
#   'bf',
#   '..',
#   'I',
#   'will',
#   'NOT',
#   'call',
#   '..',
#   'not',
#   'a',
#   'bugaboo',
#   'type'],
#  ['2',
#   'hear',
#   'about',
#   'jon',
#   'n',
#   'kate',
#   '...',
#   'couple',
#   'should',
#   'steer',
#   'clear',
#   'of',
#   'those',
#   'reality',
#   'show',
#   '!',
#   'just',
#   'say',
#   'no',
#   '!'],
#  ['--',
#   '-',
#   '2009',
#   'NCAA',
#   'National',
#   'Softball',
#   'Champions',
#   'UW',
#   'Huskies'],
#  ['2nd',
#   'item',
#   'did',
#   'not',
#   'arrive',
#   ',',
#   'am',
#   'still',
#   'waiting',
#   'for',
#   'it',
#   'to',
#   'show',
#   'in',
#   'my',
#   'aramex',
#   'web',
#   'page',
#   '.'],
#  ['Finished',
#   'my',
#   'paper',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'But',
#   '............',
#   'smh'],
#  ['first',
#   'day',
#   'are',
#   'always',
#   'good',
#   '..',
#   'wish',
#   'my',
#   'dentist',
#   'gave',
#   'me',
#   'more',
#   'hour',
#   'though'],
#  ['fone',
#   'off',
#   '....',
#   'cant',
#   'talk',
#   '2',
#   'my',
#   'love',
#   '....',
#   'imu',
#   'marcus',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['for',
#   'the',
#   'fact',
#   'that',
#   '*',
#   'I',
#   '*',
#   'did',
#   "n't",
#   'get',
#   'any',
#   'work',
#   'done',
#   ',',
#   'not',
#   'that',
#   'you',
#   'all',
#   'did',
#   '.'],
#  ['forgot',
#   'XBL',
#   'wa',
#   'off',
#   'today',
#   ',',
#   'wa',
#   'about',
#   'to',
#   'check',
#   'to',
#   'see',
#   'if',
#   'a',
#   'game',
#   'wa',
#   'on',
#   'XBLA',
#   'that',
#   'I',
#   'wanted',
#   'to',
#   'buy',
#   'oh',
#   'well',
#   ',',
#   'maybe',
#   'tomorrow'],
#  ['found',
#   'a',
#   'mosquito',
#   'bite',
#   '.',
#   '(',
#   'Those',
#   'tend',
#   'to',
#   'get',
#   'really',
#   'swollen',
#   'and',
#   'red',
#   'for',
#   'me',
#   ')',
#   'Distracting',
#   'myself',
#   'with',
#   'caffeine'],
#  ['Found', 'a', 'way', 'to', 'make', 'this', 'Private', 'woot', 'woot'],
#  ['Four',
#   'more',
#   'fake',
#   'people',
#   'added',
#   'me',
#   '.',
#   'Is',
#   'this',
#   'why',
#   'people',
#   'do',
#   "n't",
#   'like',
#   'Twitter',
#   '?'],
#  ['frank',
#   'iero',
#   'should',
#   'be',
#   'the',
#   'sexiest',
#   'vegetarian',
#   '2009',
#   '.'],
#  ['french', 'lost', ',', '#', 'fb'],
#  ['fuck',
#   'man',
#   '.i',
#   'hate',
#   'this',
#   '.',
#   '=O',
#   '.',
#   'work',
#   'suck',
#   ':',
#   "'",
#   '('],
#  ['fuck', 'you', ',', ':', ']'],
#  ['-',
#   'fuck',
#   ',',
#   'my',
#   'money',
#   'is',
#   'running',
#   'out',
#   '&',
#   'amp',
#   ';',
#   'i',
#   'have',
#   'no',
#   'job',
#   '...'],
#  ['fuck', '.', 'I', 'am', 'an', 'ugly', 'person', '.'],
#  ['fucking', 'rur', 'mom'],
#  ...]

# %%
##revised_data.drop_duplicates(subset='')

# %% [markdown]
# ### Preparing Data

# %% [markdown]
# #### Bag of Words
# We are going to use the Bag of Words algorithm, which basically takes a text as input, extract words from it (this is our vocabulary) to use them in the vectorization process. When a tweet comes in, it will vectorize it by counting the number of occurrences of each word in our vocabulary.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #### Building the pipeline

# %%
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.pipeline import Pipeline

# %%
class TextPreProc(BaseEstimator,TransformerMixin):
    def __init__(self, use_mention=False):
        self.use_mention = use_mention
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        # We can choose between keeping the mentions
        # or deleting them
        if self.use_mention:
            X = X.str.replace(r"@[a-zA-Z0-9_]* ", " @tags ")
        else:
            X = X.str.replace(r"@[a-zA-Z0-9_]* ", "")
            
        # Keeping only the word after the #
        X = X.str.replace("#", "")
        X = X.str.replace(r"[-\.\n]", "")
        # Removing HTML garbage
        X = X.str.replace(r"&\w+;", "")
        # Removing links
        X = X.str.replace(r"https?://\S*", "")
        # replace repeated letters with only two occurences
        # heeeelllloooo => heelloo
        X = X.str.replace(r"(.)\1+", r"\1\1")
        # mark emoticons as happy or sad
        X = X.str.replace(HAPPY_EMO, " happyemoticons ")
        X = X.str.replace(SAD_EMO, " sademoticons ")
        X = X.str.lower()
        return X

# %%
##inserted later
#trans(train_data.SentimentText.str.cat())
train_data
# Out:
#        ItemID  Sentiment                                      SentimentText  \
# 0           1          0                       is so sad for my APL frie...
# 1           2          0                     I missed the New Moon trail...
# 2           3          1                            omg its already 7:30 :O
# 3           4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5          0           i think mi bf is cheating on me!!!   ...
# ...       ...        ...                                                ...
# 99984   99996          0  @Cupcake  seems like a repeating problem   hop...
# 99985   99997          1  @cupcake__ arrrr we both replied to each other...
# 99986   99998          0                     @CuPcAkE_2120 ya i thought so
# 99987   99999          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99988  100000          1                    @cupcake_kayla haha yes you do
#
#                                 lemmatized_SentimentText
# 0      [is, so, sad, for, my, APL, friend, .............
# 1              [I, missed, the, New, Moon, trailer, ...]
# 2                         [omg, it, already, 7:30, :, O]
# 3      [.., Omgaga, ., Im, sooo, im, gunna, CRy, ., I...
# 4      [i, think, mi, bf, is, cheating, on, me, !, !,...
# ...                                                  ...
# 99984  [@, Cupcake, seems, like, a, repeating, proble...
# 99985  [@, cupcake__, arrrr, we, both, replied, to, e...
# 99986              [@, CuPcAkE_2120, ya, i, thought, so]
# 99987  [@, Cupcake_Dollie, Yes, ., Yes, ., I, 'm, gla...
# 99988             [@, cupcake_kayla, haha, yes, you, do]
#
# [99989 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

sentiments = train_data['Sentiment']
tweets = train_data['SentimentText']

# I get those parameters from the 'Fine tune the model' part
vectorizer = TfidfVectorizer(tokenizer=lemmatize_tokenize, ngram_range=(1,2))
pipeline = Pipeline([
    ('text_pre_processing', TextPreProc(use_mention=True)),
    ('vectorizer', vectorizer),
])

# %% [markdown]
# #### Splitting the data into learning and testing set

# %%
learn_data, test_data, sentiments_learning, sentiments_test = train_test_split(tweets, sentiments, test_size=0.3)

# %%
#transforming learning data from simple text into vector
learning_data = pipeline.fit_transform(learn_data)

# %% [markdown]
# ### Selecting a model

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

lr = LogisticRegression()
bnb = BernoulliNB()
mnb = MultinomialNB()

models = {
    'logitic regression': lr,
    'bernoulliNB': bnb,
    'multinomialNB': mnb,
}

for model in models.keys():
    scores = cross_val_score(models[model], learning_data, sentiments_learning, scoring="f1", cv=10)
    print("===", model, "===")
    print("scores = ", scores)
    print("mean = ", scores.mean())
    print("variance = ", scores.var())
    models[model].fit(learning_data, sentiments_learning)[:8000]
    print("score on the learning data (accuracy) = ", accuracy_score(models[model].predict(learning_data), sentiments_learning))
    print("")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# === logitic regression ===
# scores =  [0.8082076  0.80792273 0.81591074 0.81273454 0.81613372 0.8092978
#  0.80983527 0.81401813 0.81273637 0.81819281]
# mean =  0.8124989711572963
# variance =  1.1639177628605304e-05
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-4b6963662e2e> in <module>
#      20     print("mean = ", scores.mean())
#      21     print("variance = ", scores.var())
# ---> 22     models[model].fit(learning_data, sentiments_learning)[:8000]
#      23     print("score on the learning data (accuracy) = ", accuracy_score(models[model].predict(learning_data), sentiments_learning))
#      24     print("")
#
# TypeError: 'LogisticRegression' object is not subscriptable

# %% [markdown]
# Choosing MultinomialNB

# %% [markdown]
# ### Fine tuning the model

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search_pipeline = Pipeline([
    ('text_pre_processing', TextPreProc()),
    ('vectorizer', TfidfVectorizer()),
    ('model', MultinomialNB())
])

params = [
    {
        'text_pre_processing__use_mention' : [True, False],
        'vectorizer__max_features' : [1000, 2000, 5000, 10000, 20000, None],
        'vectorizer__ngram_range' : [(1,1), (1,2)],
    },
]

# %%
grid_search = GridSearchCV(grid_search_pipeline, params, cv=5, scoring='f1')
grid_search.fit(learn_data, sentiments_learning)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('text_pre_processing', TextPreProc()),
#                                        ('vectorizer', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              param_grid=[{'text_pre_processing__use_mention': [True, False],
#                           'vectorizer__max_features': [1000, 2000, 5000, 10000,
#                                                        20000, None],
#                           'vectorizer__ngram_range': [(1, 1), (1, 2)]}],
#              scoring='f1')

# %%
print(grid_search.best_params_)
# Out:
# {'text_pre_processing__use_mention': True, 'vectorizer__max_features': None, 'vectorizer__ngram_range': (1, 2)}

# %% [markdown]
# ### Testing

# %%
mnb.fit(learning_data, sentiments_learning)
# Out:
# MultinomialNB()

# %%
testing_data = pipeline.transform(test_data)
mnb.score(testing_data, sentiments_test)
# Out:
# 0.755075507550755

# %%
#predicting on test.csv
sub_data = pd.read_csv("C:/Users/HP/Twitter Sentiment Analysis/input/test.csv", encoding='ISO-8859-1')
sub_learning = pipeline.transform(sub_data.SentimentText)
sub = pd.DataFrame(sub_data.ItemID, columns=("ItemID", "Sentiment"))
sub["Sentiment"] = mnb.predict(sub_learning)
print(sub)
# Out:
#         ItemID  Sentiment
# 0            1          0
# 1            2          0
# 2            3          1
# 3            4          0
# 4            5          0
# ...        ...        ...
# 299984  299996          1
# 299985  299997          1
# 299986  299998          1
# 299987  299999          1
# 299988  300000          1
#
# [299989 rows x 2 columns]

# %%
#
#mnb.score(sub_learning,sentiments_test )
